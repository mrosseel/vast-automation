# %% [markdown]
# # Get observation count

# %% [markdown]
# ## Import modules

# %%
import os
os.chdir('/home/jovyan/work/src')
import pandas as pd
import re
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Set reference frame, global vars

# %%
resultdict = {}
# pattern = re.compile
# with open("../results/wwcra2015vast/vast_lightcurve_statistics.log", 'r') as infile:
#     for line in infile:
#         resultdict[] = 
columns = ['Median magnitude','idx00_STD','X position of the star on the reference image [pix]','Y position of the star on the reference image [pix]',
           'lightcurve file name','idx01_wSTD','idx02_skew','idx03_kurt','idx04_I','idx05_J','idx06_K','idx07_L','idx08_Npts','idx09_MAD',
           'idx10_lag1','idx11_RoMS','idx12_rCh2','idx13_Isgn','idx14_Vp2p','idx15_Jclp','idx16_Lclp','idx17_Jtim','idx18_Ltim','idx19_N3',
           'idx20_excr','idx21_eta','idx22_E_A','idx23_S_B','idx24_NXS','idx25_IQR','idx26_A01','idx27_A02','idx28_A03','idx29_A04','idx30_A05',
]
df = pd.read_csv("../inputfiles/wwcra2015vast/vast_lightcurve_statistics.log", names=columns, delim_whitespace=True)        
df.head()
# for index, row in df.iterrows():
#     print(row['lightcurve file name'], row['idx08_Npts'])
# Out:
#    Median magnitude  idx00_STD  \
# 0         10.150421   0.019022
# 1         10.235427   0.011365
# 2         10.250255   0.016696
# 3         10.295033   0.020697
# 4         10.299078   0.011238
#
#    X position of the star on the reference image [pix]  \
# 0                                          481.60931
# 1                                          781.57861
# 2                                         1031.70239
# 3                                          506.37799
# 4                                          848.34442
#
#    Y position of the star on the reference image [pix] lightcurve file name  \
# 0                                          713.15588           out03098.dat
# 1                                          344.07880           out04804.dat
# 2                                         1230.45667           out00958.dat
# 3                                          303.99069           out04978.dat
# ...
