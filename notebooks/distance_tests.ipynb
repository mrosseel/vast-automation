# %%
import os
os.chdir('..')
import init
import pandas as pd
import reading
from astropy.coordinates import SkyCoord

target_ra_deg = init.ra_deg
target_dec_deg = init.dec_deg

target = SkyCoord(target_ra_deg, target_dec_deg, unit='deg')
result_dict = reading.read_world_positions(init.worldposdir)
distances_dict = {}
for key in result_dict:
    distances_dict[key] = target.separation(SkyCoord(result_dict[key][0], result_dict[key][1], unit='deg')).degree
print(distances_dict)
#df = pd.DataFrame.from_dict(distances_dict, orient='index')
df = pd.DataFrame(list(distances_dict.items()), columns=['filename', 'deg_separation'])
df.sort(columns='deg_separation', inplace=True)
df.head()
# Out:
# {'worldpos_00001.txt': 0.14053659915653874, 'worldpos_00002.txt': 0.30311703780194027, 'worldpos_00003.txt': 0.3001691326473064, 'worldpos_00004.txt': 0.1833723938863608, 'worldpos_00005.txt': 0.2762884815596999, 'worldpos_00006.txt': 0.23508484981698216, 'worldpos_00007.txt': 0.29994764282313885, 'worldpos_00008.txt': 0.35204093207911424, 'worldpos_00009.txt': 0.40183820598771147, 'worldpos_00010.txt': 0.2140934368677666, 'worldpos_00011.txt': 0.09801388744920567, 'worldpos_00012.txt': 0.5263698416128623, 'worldpos_00013.txt': 0.15543683280829712, 'worldpos_00014.txt': 0.14108041112403916, 'worldpos_00015.txt': 0.49378347838082615, 'worldpos_00016.txt': 0.08383119080345497, 'worldpos_00017.txt': 0.426553087220353, 'worldpos_00018.txt': 0.5143996657800466, 'worldpos_00019.txt': 0.36971963355039383, 'worldpos_00020.txt': 0.26035990502169754, 'worldpos_00021.txt': 0.35051558524672494, 'worldpos_00022.txt': 0.30076932689341584, 'worldpos_00023.txt': 0.27100623612955804, 'worldpos_00024.txt': 0.14813294519268908, 'worldpos_00025.txt': 0.5519047884571312, 'worldpos_00026.txt': 0.10637202739681653, 'worldpos_00027.txt': 0.32604597968936977, 'worldpos_00028.txt': 0.14438322879723164, 'worldpos_00029.txt': 0.07880653521368085, 'worldpos_00030.txt': 0.19464692725278684, 'worldpos_00031.txt': 0.26927650147597587, 'worldpos_00032.txt': 0.10356701125158957, 'worldpos_00033.txt': 0.2342595724359684, 'worldpos_00034.txt': 0.41411651989455317, 'worldpos_00035.txt': 0.3292287133624658, 'worldpos_00036.txt': 0.4694902970084694, 'worldpos_00037.txt': 0.40357024864528873, 'worldpos_00038.txt': 0.23576145732762507, 'worldpos_00039.txt': 0.48342095358260384, 'worldpos_00040.txt': 0.1507260986712641, 'worldpos_00041.txt': 0.27008882356448477, 'worldpos_00042.txt': 0.188433927520282, 'worldpos_00043.txt': 0.23464798185015495, 'worldpos_00044.txt': 0.31332097983244045, 'worldpos_00045.txt': 0.36507560032619707, 'worldpos_00046.txt': 0.6208433656849756, 'worldpos_00047.txt': 0.340845849198134, 'worldpos_00048.txt': 0.5435529088766785, 'worldpos_00049.txt': 0.5290093303315652, 'worldpos_00050.txt': 0.44278151917644387, 'worldpos_00051.txt': 0.45011702128514913, 'worldpos_00052.txt': 0.44831412015964306, 'worldpos_00053.txt': 0.3187958338162112, 'worldpos_00054.txt': 0.24028089817864687, 'worldpos_00055.txt': 0.3297649315191685, 'worldpos_00056.txt': 0.3075858378285362, 'worldpos_00057.txt': 0.33428094120570223, 'worldpos_00058.txt': 0.2620203772965711, 'worldpos_00059.txt': 0.5045487881551811, 'worldpos_00060.txt': 0.304976896805792, 'worldpos_00061.txt': 0.3138996406489186, 'worldpos_00062.txt': 0.39579269668240735, 'worldpos_00063.txt': 0.1821023990550576, 'worldpos_00064.txt': 0.2940465983605365, 'worldpos_00065.txt': 0.24680910686259067, 'worldpos_00066.txt': 0.5917714935116252, 'worldpos_00067.txt': 0.23478866707396126, 'worldpos_00068.txt': 0.49116532411844205, 'worldpos_00069.txt': 0.4775589026581422, 'worldpos_00070.txt': 0.17694309210716944, 'worldpos_00071.txt': 0.5641704637488425, 'worldpos_00072.txt': 0.20322995179838116, 'worldpos_00073.txt': 0.29639561568939266, 'worldpos_00074.txt': 0.4218455826625975, 'worldpos_00075.txt': 0.35910547773512347, 'worldpos_00076.txt': 0.27671176532108954, 'worldpos_00077.txt': 0.5250810654061562, 'worldpos_00078.txt': 0.18463550875463156, 'worldpos_00079.txt': 0.295347528779929, 'worldpos_00080.txt': 0.3485444597801686, 'worldpos_00081.txt': 0.48762398529223305, 'worldpos_00082.txt': 0.19910559627343047, 'worldpos_00083.txt': 0.2129661747543639, 'worldpos_00084.txt': 0.26249151138110394, 'worldpos_00085.txt': 0.33374659640488247, 'worldpos_00086.txt': 0.18436690042612444, 'worldpos_00087.txt': 0.4042647439375898, 'worldpos_00088.txt': 0.3611877911149906, 'worldpos_00089.txt': 0.1242264189894332, 'worldpos_00090.txt': 0.6047946314719206, 'worldpos_00091.txt': 0.47822716847933877, 'worldpos_00092.txt': 0.2425368981690904, 'worldpos_00093.txt': 0.18766253239128425, 'worldpos_00094.txt': 0.4892112607227737, 'w ...
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:19: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#                filename  deg_separation
# 137  worldpos_00138.txt        0.000372
# 250  worldpos_00251.txt        0.023691
# 460  worldpos_00461.txt        0.028439
# 378  worldpos_00379.txt        0.029585
# 849  worldpos_00850.txt        0.039456

# %%
df.min()
# Out:
# filename          worldpos_00001.txt
# deg_separation           0.000372233
# dtype: object

# %%
print(df.head())
# Out:
#                filename  deg_separation
# 137  worldpos_00138.txt        0.000372
# 250  worldpos_00251.txt        0.023691
# 460  worldpos_00461.txt        0.028439
# 378  worldpos_00379.txt        0.029585
# 849  worldpos_00850.txt        0.039456

# %%
df[:3]
# Out:
#                filename  deg_separation
# 137  worldpos_00138.txt        0.000372
# 250  worldpos_00251.txt        0.023691
# 460  worldpos_00461.txt        0.028439

# %%
wwcra = [271.4032885585627, -43.8322388739166]
coord = SkyCoord(wwcra[0], wwcra[1], unit='deg')
print(coord.ra.hms, coord.dec.dms)
# Out:
# hms_tuple(h=18.0, m=5.0, s=36.78925405505993) dms_tuple(d=-43.0, m=-49.0, s=-56.059946099765625)

# %%
dir(coord.ra.hms)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '_asdict',
#  '_fields',
#  '_make',
#  '_replace',
#  '_source',
#  'count',
#  'h',
#  'index',
#  'm',
#  's']
