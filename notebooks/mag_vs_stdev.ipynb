# %%
# IMPORT
import os
os.chdir('..')
import init
import pandas as pd
import numpy as np
import matplotlib as mp
import matplotlib.pyplot as plt
import seaborn as sns

#from astropy import wcs
#from astropy.io import fits
#from astropy.coordinates import SkyCoord
#from astropy.vo.client import conesearch
#from astropy import units as u

# %% [markdown]
# Read the Munifind file to get STDEV of all stars

# %%
# INDEX MEAN_MAG STDEV GOODPOINTS
def read_munifind(filename):
    df = pd.read_csv(filename, skiprows=[1], sep=' ')
    df.rename(columns = {'INDEX':'STAR'}, inplace = True)
    print("max goodpoints:", df['GOODPOINTS'].max())
    print("min stdev:", df['STDEV'].min())
    print(df.sort_values('STDEV').head())
    return df
df = read_munifind(init.basedir+'munifind.txt')
# Out:
# max goodpoints: 10382
# min stdev: 0.01835
#     STAR  MEAN_MAG    STDEV  GOODPOINTS
# 71    87  -0.34067  0.01835       10327
# 14    17  -2.39894  0.01931       10382
# 0      3  -3.42066  0.01990        8241
# 11    12  -2.45909  0.02053       10314
# 5      8  -2.61263  0.02143       10378

# %%
# %matplotlib inline
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111)
x = df['MEAN_MAG']
y = df['STDEV']
z = df['GOODPOINTS']
realx = x
realy = y
ax.plot(realx, realy, '.')
for i, d in enumerate(x):
    ax.annotate(df['STAR'][i], (realx[i],realy[i]))

# %%
def getBestComparisonStars():
    result = []
    # TODO: filter all stars which have not the maximum of GOODPOINTS
    df_lowest_stdev = df.sort_values('STDEV')
    return df_lowest_stdev.head(10)
    
bestcomps = getBestComparisonStars()
print(bestcomps)
check_stars = []
for index, row in bestcomps.iterrows():
    #print(row, '\n')
    check_stars.append(int(row['STAR']))
check_stars_str = ','.join(map(str, check_stars)) 
print(check_stars_str)
# Out:
#      STAR  MEAN_MAG    STDEV  GOODPOINTS
# 48     61   1.48797  0.00572         893
# 23     30   0.98170  0.00738         864
# 143   171   2.47843  0.00776         889
# 41     48   1.27522  0.00789         831
# 64     77   1.72525  0.00791         884
# 44     55   1.32499  0.00804         841
# 80     97   1.89205  0.00848         886
# 72     87   1.82416  0.00864         848
# 136   164   2.43789  0.00891         796
# 142   172   2.47665  0.00932         891
# 61,30,171,48,77,55,97,87,164,172

# %%
print(df.iloc[143])
# Out:
# STAR          171.00000
# MEAN_MAG        2.47843
# STDEV           0.00776
# GOODPOINTS    889.00000
# Name: 143, dtype: float64

# %%
select_star_list = [143,6394,598,2675,3111,2584]
single_star_list = [598]
star_list = init.all_star_list

# %%
def set_seaborn_style():
    sns.set_context("notebook", font_scale=1.1)
    sns.set_style("ticks")

def read_lightcurve(star):
    print("Reading lightcurve", star)
    df = pd.read_csv(init.lightcurvedir + str(star) + '.txt', skiprows=[1], sep=' ')
    df = df[df['V-C'] < 99]
    return df

def read_pos(star):
    df = pd.read_csv(init.lightcurvedir + 'pos_' + str(star) + '.txt', skiprows=[1], sep=' ')
    df = df[df['X'] > 0]
    df = df[df['MAG'] < 99]
    return (df['X'].iloc[1], df['Y'].iloc[1])

def plot_lightcurve(df2, pos, name):
    #insert counting column
    df2.insert(0, 'Count', range(0, len(df2)))
    g = sns.lmplot('Count', 'V-C', 
               data=df2, 
               fit_reg=False)
    plt.title('Star '+ str(name))
    #+ " : " + pixel_to_radec(wcs_config, pos[0], pos[1]).to_string('hmsdms') + ' - ' +str(pos[0]) + ', ' + str(pos[1]))
    plt.xlabel('Obs #')
    plt.ylabel('Mag')    
    plt.gca().invert_yaxis()
    plt.ticklabel_format(style='plain', axis='x')
    plt.figure(figsize=(70,10)) 
    #sns.plt.show()
    g.savefig(init.lightcurvedir+str(star))
    plt.cla()
    
set_seaborn_style()
try:
    for star in star_list:
        plot_lightcurve(read_lightcurve(star), read_pos(star), star)
except D:
    print("D", D)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-799b20c16ba1> in <module>()
#      32     plt.cla()
#      33
# ---> 34 set_seaborn_style()
#      35 try:
#      36     for star in star_list:
#
# <ipython-input-1-799b20c16ba1> in set_seaborn_style()
#       1 def set_seaborn_style():
# ----> 2     sns.set_context("notebook", font_scale=1.1)
#       3     sns.set_style("ticks")
#       4
#       5 def read_lightcurve(star):
#
# NameError: name 'sns' is not defined

# %%
import upsilon
upsilon.test_predict()
# Out:
# 2017-01-22 20:37:02,615 INFO - Read a light curve
# 2017-01-22 20:37:02,623 INFO -    Before sigma-clipping: 551 data points
# 2017-01-22 20:37:02,624 INFO -    After sigma-clipping: 551 data points
# 2017-01-22 20:37:03,308 INFO - Feature extracting time: 0.6843 seconds
# 2017-01-22 20:37:03,309 INFO - Extracted features. 16 of these, marked with (+) are used to predict a class:
# 2017-01-22 20:37:03,309 INFO -    (+) amplitude: 0.097430
# 2017-01-22 20:37:03,310 INFO -    (-) cusum: 0.070156
# 2017-01-22 20:37:03,310 INFO -    (-) eta: 2.428789
# 2017-01-22 20:37:03,311 INFO -    (+) hl_amp_ratio: 0.703306
# 2017-01-22 20:37:03,311 INFO -    (+) kurtosis: -1.197611
# 2017-01-22 20:37:03,311 INFO -    (-) n_points: 551
# 2017-01-22 20:37:03,312 INFO -    (+) period: 4.190441
# 2017-01-22 20:37:03,312 INFO -    (-) period_SNR: 148.150908
# 2017-01-22 20:37:03,312 INFO -    (-) period_log10FAP: -99.703012
# 2017-01-22 20:37:03,313 INFO -    (-) period_uncertainty: 0.007102
# 2017-01-22 20:37:03,313 INFO -    (+) phase_cusum: 0.222157
# 2017-01-22 20:37:03,313 INFO -    (+) phase_eta: 0.173238
# 2017-01-22 20:37:03,314 INFO -    (+) phi21: 0.935884
# 2017-01-22 20:37:03,314 INFO -    (+) phi31: -1.362440
# 2017-01-22 20:37:03,314 INFO -    (+) quartile31: 0.134000
# 2017-01-22 20:37:03,315 INFO -    (+) r21: 0.187627
# 2017-01-22 20:37:03,315 INFO -    (+) r31: 0.073064
# 2017-01-22 20:37:03,316 INFO -    (+) shapiro_w: 0.944696
# 2017-01-22 20:37:03,316 INFO -    (+) skewness: -0.222401
# 2017-01-22 20:37:03,316 INFO -    (+) slope_per10: -2.349005
# 2017-01-22 20:37:03,317 INFO -    (+) slope_per90: 2.166852
# 2017-01-22 20:37:03,317 INFO -    (+) stetson_k: 0.854120
# 2017-01-22 20:37:03,318 INFO -    (-) weighted_mean: 14.815209
# 2017-01-22 20:37:03,318 INFO -    (-) weighted_std: 0.073511
# 2017-01-22 20:37:03,319 INFO - Load the UPSILoN classifier
# 2017-01-22 20:37:05,027 INFO - Classify the light curve
# 2017-01-22 20:37:05,132 INFO -    Classified as CEPH_1O with the class probability 0.92
# 2017-01-22 20:37:05,132 INFO -    Classification flag: 0

# %%
rf_model = upsilon.load_rf_model()
for star in all_star_list:
    try:
        df = read_lightcurve(star)
        mag = df['V-C']
        date = df.index.values
        e_features = upsilon.ExtractFeatures(date, mag)
        e_features.run()
        features = e_features.get_features()

        # Classify the light curve
        label, probability, flag = upsilon.predict(rf_model, features)
        print("star, label, probability, flag")
        print(star, label, probability, flag)
    except:
        print(star, 'error')
# Out:
# Reading lightcurve 1
# 1 error
# Reading lightcurve 2
# 2 error
# Reading lightcurve 3
# 3 error
# Reading lightcurve 4
# 4 error
# Reading lightcurve 5
# 5 error
# Reading lightcurve 6
# 6 error
# Reading lightcurve 7
# 7 error
# Reading lightcurve 8
# 8 error
# Reading lightcurve 9
# 9 error
# Reading lightcurve 10
# 10 error
# Reading lightcurve 11
# 11 error
# Reading lightcurve 12
# 12 error
# Reading lightcurve 13
# 13 error
# Reading lightcurve 14
# 14 error
# Reading lightcurve 15
# 15 error
# Reading lightcurve 16
# 16 error
# Reading lightcurve 17
# 17 error
# Reading lightcurve 18
# 18 error
# Reading lightcurve 19
# 19 error
# Reading lightcurve 20
# 20 error
# Reading lightcurve 21
# 21 error
# Reading lightcurve 22
# 22 error
# Reading lightcurve 23
# 23 error
# Reading lightcurve 24
# 24 error
# Reading lightcurve 25
# 25 error
# Reading lightcurve 26
# 26 error
# Reading lightcurve 27
# 27 error
# Reading lightcurve 28
# 28 error
# Reading lightcurve 29
# 29 error
# Reading lightcurve 30
# 30 error
# Reading lightcurve 31
# 31 error
# Reading lightcurve 32
# 32 error
# Reading lightcurve 33
# 33 error
# Reading lightcurve 34
# 34 error
# Reading lightcurve 35
# 35 error
# Reading lightcurve 36
# 36 error
# Reading lightcurve 37
# 37 error
# Reading lightcurve 38
# 38 error
# Reading lightcurve 39
# 39 error
# Reading lightcurve 40
# 40 error
# Reading lightcurve 41
# 41 error
# Reading lightcurve 42
# 42 error
# Reading lightcurve 43
# 43 error
# Reading lightcurve 44
# 44 error
# Reading lightcurve 45
# 45 error
# Reading lightcurve 46
# 46 error
# Reading lightcurve 47
# 47 error
# Reading lightcurve 48
# 48 error
# Reading lightcurve 49
# 49 error
# Reading lightcurve 50
# 50 error
# Reading lightcurve 51
# 51 error
# Reading lightcurve 52
# 52 error
# Reading lightcurve 53
# 53 error
# Reading lightcurve 54
# 54 error
# Reading lightcurve 55
# 55 error
# Reading lightcurve 56
# 56 error
# Reading lightcurve 57
# 57 error
# Reading lightcurve 58
# 58 error
# Reading lightcurve 59
# 59 error
# Reading lightcurve 60
# 60 error
# Reading lightcurve 61
# 61 error
# Reading lightcurve 62
# 62 error
# Reading lightcurve 63
# 63 error
# Reading lightcurve 64
# 64 error
# Reading lightcurve 65
# 65 error
# Reading lightcurve 66
# 66 error
# Reading lightcurve 67
# 67 error
# Reading lightcurve 68
# 68 error
# Reading lightcurve 69
# 69 error
# Reading lightcurve 70
# 70 error
# Reading lightcurve 71
# 71 error
# Reading lightcurve 72
# 72 error
# Reading lightcurve 73
# 73 error
# Reading lightcurve 74
# 74 error
# Reading lightcurve 75
# 75 error
# Reading lightcurve 76
# 76 error
# Reading lightcurve 77
# 77 error
# Reading lightcurve 78
# 78 error
# Reading lightcurve 79
# 79 error
# Reading lightcurve 80
# 80 error
# Reading lightcurve 81
# 81 error
# Reading lightcurve 82
# 82 error
# Reading lightcurve 83
# 83 error
# Reading lightcurve 84
# 84 error
# Reading lightcurve 85
# 85 error
# Reading lightcurve 86
# 86 error
# Reading lightcurve 87
# 87 error
# Reading lightcurve 88
# 88 error
# Reading lightcurve 89
# 89 error
# Reading lightcurve 90
# 90 error
# Reading lightcurve 91
# 91 error
# Reading lightcurve 92
# 92 error
# Reading lightcurve 93
# 93 error
# Reading lightcurve 94
# 94 error
# Reading lightcurve 95
# 95 error
# Reading lightcurve 96
# 96 error
# Reading lightcurve 97
# 97 error
# Reading lightcurve 98
# 98 error
# Reading lightcurve 99
# 99 error
# Reading lightcurve 100
# 100 error
# Reading lightcurve 101
# 101 error
# Reading lightcurve 102
# 102 error
# Reading lightcurve 103
# 103 error
# Reading lightcurve 104
# 104 error
# Reading lightcurve 105
# 105 error
# Reading lightcurve 106
# 106 error
# Reading lightcurve 107
# 107 error
# Reading lightcurve 108
# 108 error
# Reading lightcurve 109
# 109 error
# Reading lightcurve 110
# 110 error
# Reading lightcurve 111
# 111 error
# Reading lightcurve 112
# 112 error
# Reading lightcurve 113
# 113 error
# Reading lightcurve 114
# 114 error
# Reading lightcurve 115
# 115 error
# Reading lightcurve 116
# 116 error
# Reading lightcurve 117
# 117 error
# Reading lightcurve 118
# 118 error
# Reading lightcurve 119
# 119 error
# Reading lightcurve 120
# 120 error
# Reading lightcurve 121
# 121 error
# Reading lightcurve 122
# 122 error
# Reading lightcurve 123
# 123 error
# Reading lightcurve 124
# 124 error
# Reading lightcurve 125
# 125 error
# Reading lightcurve 126
# 126 error
# Reading lightcurve 127
# 127 error
# Reading lightcurve 128
# 128 error
# Reading lightcurve 129
# 129 error
# Reading lightcurve 130
# 130 error
# Reading lightcurve 131
# 131 error
# Reading lightcurve 132
# 132 error
# Reading lightcurve 133
# 133 error
# Reading lightcurve 134
# 134 error
# Reading lightcurve 135
# 135 error
# Reading lightcurve 136
# 136 error
# Reading lightcurve 137
# 137 error
# Reading lightcurve 138
# 138 error
# Reading lightcurve 139
# 139 error
# Reading lightcurve 140
# 140 error
# Reading lightcurve 141
# 141 error
# Reading lightcurve 142
# 142 error
# Reading lightcurve 143
# star, label, probability, flag
# 143 LPV_SRV_AGB_O 0.32 1
# Reading lightcurve 144
# 144 error
# Reading lightcurve 145
# 145 error
# Reading lightcurve 146
# 146 error
# Reading lightcurve 147
# 147 error
# Reading lightcurve 148
# 148 error
# Reading lightcurve 149
# 149 error
# Reading lightcurve 150
# 150 error
# Reading lightcurve 151
# 151 error
# Reading lightcurve 152
# 152 error
# Reading lightcurve 153
# 153 error
# Reading lightcurve 154
# 154 error
# Reading lightcurve 155
# 155 error
# Reading lightcurve 156
# 156 error
# Reading lightcurve 157
# 157 error
# Reading lightcurve 158
# 158 error
# Reading lightcurve 159
# 159 error
# Reading lightcurve 160
# 160 error
# Reading lightcurve 161
# 161 error
# Reading lightcurve 162
# 162 error
# Reading lightcurve 163
# 163 error
# Reading lightcurve 164
# 164 error
# Reading lightcurve 165
# 165 error
# Reading lightcurve 166
# 166 error
# Reading lightcurve 167
# 167 error
# Reading lightcurve 168
# 168 error
# Reading lightcurve 169
# 169 error
# Reading lightcurve 170
# 170 error
# Reading lightcurve 171
# 171 error
# Reading lightcurve 172
# 172 error
# Reading lightcurve 173
# 173 error
# Reading lightcurve 174
# 174 error
# Reading lightcurve 175
# 175 error
# Reading lightcurve 176
# 176 error
# Reading lightcurve 177
# 177 error
# Reading lightcurve 178
# 178 error
# Reading lightcurve 179
# 179 error
# Reading lightcurve 180
# 180 error
# Reading lightcurve 181
# 181 error
# Reading lightcurve 182
# 182 error
# Reading lightcurve 183
# 183 error
# Reading lightcurve 184
# 184 error
# Reading lightcurve 185
# 185 error
# Reading lightcurve 186
# 186 error
# Reading lightcurve 187
# 187 error
# Reading lightcurve 188
# 188 error
# Reading lightcurve 189
# 189 error
# Reading lightcurve 190
# 190 error
# Reading lightcurve 191
# 191 error
# Reading lightcurve 192
# 192 error
# Reading lightcurve 193
# 193 error
# Reading lightcurve 194
# 194 error
# Reading lightcurve 195
# 195 error
# Reading lightcurve 196
# 196 error
# Reading lightcurve 197
# 197 error
# Reading lightcurve 198
# 198 error
# Reading lightcurve 199
# 199 error
# Reading lightcurve 200
# 200 error
# Reading lightcurve 201
# 201 error
# Reading lightcurve 202
# 202 error
# Reading lightcurve 203
# 203 error
# Reading lightcurve 204
# 204 error
# Reading lightcurve 205
# 205 error
# Reading lightcurve 206
# 206 error
# Reading lightcurve 207
# 207 error
# Reading lightcurve 208
# 208 error
# Reading lightcurve 209
# 209 error
# Reading lightcurve 210
# 210 error
# Reading lightcurve 211
# 211 error
# Reading lightcurve 212
# 212 error
# Reading lightcurve 213
# 213 error
# Reading lightcurve 214
# 214 error
# Reading lightcurve 215
# 215 error
# Reading lightcurve 216
# 216 error
# Reading lightcurve 217
# 217 error
# Reading lightcurve 218
# 218 error
# Reading lightcurve 219
# 219 error
# Reading lightcurve 220
# 220 error
# Reading lightcurve 221
# 221 error
# Reading lightcurve 222
# 222 error
# Reading lightcurve 223
# 223 error
# Reading lightcurve 224
# 224 error
# Reading lightcurve 225
# 225 error
# Reading lightcurve 226
# 226 error
# Reading lightcurve 227
# 227 error
# Reading lightcurve 228
# 228 error
# Reading lightcurve 229
# 229 error
# Reading lightcurve 230
# 230 error
# Reading lightcurve 231
# 231 error
# Reading lightcurve 232
# 232 error
# Reading lightcurve 233
# 233 error
# Reading lightcurve 234
# 234 error
# Reading lightcurve 235
# 235 error
# Reading lightcurve 236
# 236 error
# Reading lightcurve 237
# 237 error
# Reading lightcurve 238
# 238 error
# Reading lightcurve 239
# 239 error
# Reading lightcurve 240
# 240 error
# Reading lightcurve 241
# 241 error
# Reading lightcurve 242
# 242 error
# Reading lightcurve 243
# 243 error
# Reading lightcurve 244
# 244 error
# Reading lightcurve 245
# 245 error
# Reading lightcurve 246
# 246 error
# Reading lightcurve 247
# 247 error
# Reading lightcurve 248
# 248 error
# Reading lightcurve 249
# 249 error
# Reading lightcurve 250
# 250 error
# Reading lightcurve 251
# 251 error
# Reading lightcurve 252
# 252 error
# Reading lightcurve 253
# 253 error
# Reading lightcurve 254
# 254 error
# Reading lightcurve 255
# 255 error
# Reading lightcurve 256
# 256 error
# Reading lightcurve 257
# 257 error
# Reading lightcurve 258
# 258 error
# Reading lightcurve 259
# 259 error
# Reading lightcurve 260
# 260 error
# Reading lightcurve 261
# 261 error
# Reading lightcurve 262
# 262 error
# Reading lightcurve 263
# 263 error
# Reading lightcurve 264
# 264 error
# Reading lightcurve 265
# 265 error
# Reading lightcurve 266
# 266 error
# Reading lightcurve 267
# 267 error
# Reading lightcurve 268
# 268 error
# Reading lightcurve 269
# 269 error
# Reading lightcurve 270
# 270 error
# Reading lightcurve 271
# 271 error
# Reading lightcurve 272
# 272 error
# Reading lightcurve 273
# 273 error
# Reading lightcurve 274
# 274 error
# Reading lightcurve 275
# 275 error
# Reading lightcurve 276
# 276 error
# Reading lightcurve 277
# 277 error
# Reading lightcurve 278
# 278 error
# Reading lightcurve 279
# 279 error
# Reading lightcurve 280
# 280 error
# Reading lightcurve 281
# 281 error
# Reading lightcurve 282
# 282 error
# Reading lightcurve 283
# 283 error
# Reading lightcurve 284
# 284 error
# Reading lightcurve 285
# 285 error
# Reading lightcurve 286
# 286 error
# Reading lightcurve 287
# 287 error
# Reading lightcurve 288
# 288 error
# Reading lightcurve 289
# 289 error
# Reading lightcurve 290
# 290 error
# Reading lightcurve 291
# 291 error
# Reading lightcurve 292
# 292 error
# Reading lightcurve 293
# 293 error
# Reading lightcurve 294
# 294 error
# Reading lightcurve 295
# 295 error
# Reading lightcurve 296
# 296 error
# Reading lightcurve 297
# 297 error
# Reading lightcurve 298
# 298 error
# Reading lightcurve 299
# 299 error
# Reading lightcurve 300
# 300 error
# Reading lightcurve 301
# 301 error
# Reading lightcurve 302
# 302 error
# Reading lightcurve 303
# 303 error
# Reading lightcurve 304
# 304 error
# Reading lightcurve 305
# 305 error
# Reading lightcurve 306
# 306 error
# Reading lightcurve 307
# 307 error
# Reading lightcurve 308
# 308 error
# Reading lightcurve 309
# 309 error
# Reading lightcurve 310
# 310 error
# Reading lightcurve 311
# 311 error
# Reading lightcurve 312
# 312 error
# Reading lightcurve 313
# 313 error
# Reading lightcurve 314
# 314 error
# Reading lightcurve 315
# 315 error
# Reading lightcurve 316
# 316 error
# Reading lightcurve 317
# 317 error
# Reading lightcurve 318
# 318 error
# Reading lightcurve 319
# 319 error
# Reading lightcurve 320
# 320 error
# Reading lightcurve 321
# 321 error
# Reading lightcurve 322
# 322 error
# Reading lightcurve 323
# 323 error
# Reading lightcurve 324
# 324 error
# Reading lightcurve 325
# 325 error
# Reading lightcurve 326
# 326 error
# Reading lightcurve 327
# 327 error
# Reading lightcurve 328
# 328 error
# Reading lightcurve 329
# 329 error
# Reading lightcurve 330
# 330 error
# Reading lightcurve 331
# 331 error
# Reading lightcurve 332
# 332 error
# Reading lightcurve 333
# 333 error
# Reading lightcurve 334
# 334 error
# Reading lightcurve 335
# 335 error
# Reading lightcurve 336
# 336 error
# Reading lightcurve 337
# 337 error
# Reading lightcurve 338
# 338 error
# Reading lightcurve 339
# 339 error
# Reading lightcurve 340
# 340 error
# Reading lightcurve 341
# 341 error
# Reading lightcurve 342
# 342 error
# Reading lightcurve 343
# 343 error
# Reading lightcurve 344
# 344 error
# Reading lightcurve 345
# 345 error
# Reading lightcurve 346
# 346 error
# Reading lightcurve 347
# 347 error
# Reading lightcurve 348
# 348 error
# Reading lightcurve 349
# 349 error
# Reading lightcurve 350
# 350 error
# Reading lightcurve 351
# 351 error
# Reading lightcurve 352
# 352 error
# Reading lightcurve 353
# 353 error
# Reading lightcurve 354
# 354 error
# Reading lightcurve 355
# 355 error
# Reading lightcurve 356
# 356 error
# Reading lightcurve 357
# 357 error
# Reading lightcurve 358
# 358 error
# Reading lightcurve 359
# 359 error
# Reading lightcurve 360
# 360 error
# Reading lightcurve 361
# 361 error
# Reading lightcurve 362
# 362 error
# Reading lightcurve 363
# 363 error
# Reading lightcurve 364
# 364 error
# Reading lightcurve 365
# 365 error
# Reading lightcurve 366
# 366 error
# Reading lightcurve 367
# 367 error
# Reading lightcurve 368
# 368 error
# Reading lightcurve 369
# 369 error
# Reading lightcurve 370
# 370 error
# Reading lightcurve 371
# 371 error
# Reading lightcurve 372
# 372 error
# Reading lightcurve 373
# 373 error
# Reading lightcurve 374
# 374 error
# Reading lightcurve 375
# 375 error
# Reading lightcurve 376
# 376 error
# Reading lightcurve 377
# 377 error
# Reading lightcurve 378
# 378 error
# Reading lightcurve 379
# 379 error
# Reading lightcurve 380
# 380 error
# Reading lightcurve 381
# 381 error
# Reading lightcurve 382
# 382 error
# Reading lightcurve 383
# 383 error
# Reading lightcurve 384
# 384 error
# Reading lightcurve 385
# 385 error
# Reading lightcurve 386
# 386 error
# Reading lightcurve 387
# 387 error
# Reading lightcurve 388
# 388 error
# Reading lightcurve 389
# 389 error
# Reading lightcurve 390
# 390 error
# Reading lightcurve 391
# 391 error
# Reading lightcurve 392
# 392 error
# Reading lightcurve 393
# 393 error
# Reading lightcurve 394
# 394 error
# Reading lightcurve 395
# 395 error
# Reading lightcurve 396
# 396 error
# Reading lightcurve 397
# 397 error
# Reading lightcurve 398
# 398 error
# Reading lightcurve 399
# 399 error
# Reading lightcurve 400
# 400 error
# Reading lightcurve 401
# 401 error
# Reading lightcurve 402
# 402 error
# Reading lightcurve 403
# 403 error
# Reading lightcurve 404
# 404 error
# Reading lightcurve 405
# 405 error
# Reading lightcurve 406
# 406 error
# Reading lightcurve 407
# 407 error
# Reading lightcurve 408
# 408 error
# Reading lightcurve 409
# 409 error
# Reading lightcurve 410
# 410 error
# Reading lightcurve 411
# 411 error
# Reading lightcurve 412
# 412 error
# Reading lightcurve 413
# 413 error
# Reading lightcurve 414
# 414 error
# Reading lightcurve 415
# 415 error
# Reading lightcurve 416
# 416 error
# Reading lightcurve 417
# 417 error
# Reading lightcurve 418
# 418 error
# Reading lightcurve 419
# 419 error
# Reading lightcurve 420
# 420 error
# Reading lightcurve 421
# 421 error
# Reading lightcurve 422
# 422 error
# Reading lightcurve 423
# 423 error
# Reading lightcurve 424
# 424 error
# Reading lightcurve 425
# 425 error
# Reading lightcurve 426
# 426 error
# Reading lightcurve 427
# 427 error
# Reading lightcurve 428
# 428 error
# Reading lightcurve 429
# 429 error
# Reading lightcurve 430
# 430 error
# Reading lightcurve 431
# 431 error
# Reading lightcurve 432
# 432 error
# Reading lightcurve 433
# 433 error
# Reading lightcurve 434
# 434 error
# Reading lightcurve 435
# 435 error
# Reading lightcurve 436
# 436 error
# Reading lightcurve 437
# 437 error
# Reading lightcurve 438
# 438 error
# Reading lightcurve 439
# 439 error
# Reading lightcurve 440
# 440 error
# Reading lightcurve 441
# 441 error
# Reading lightcurve 442
# 442 error
# Reading lightcurve 443
# 443 error
# Reading lightcurve 444
# 444 error
# Reading lightcurve 445
# 445 error
# Reading lightcurve 446
# 446 error
# Reading lightcurve 447
# 447 error
# Reading lightcurve 448
# 448 error
# Reading lightcurve 449
# 449 error
# Reading lightcurve 450
# 450 error
# Reading lightcurve 451
# 451 error
# Reading lightcurve 452
# 452 error
# Reading lightcurve 453
# 453 error
# Reading lightcurve 454
# 454 error
# Reading lightcurve 455
# 455 error
# Reading lightcurve 456
# 456 error
# Reading lightcurve 457
# 457 error
# Reading lightcurve 458
# 458 error
# Reading lightcurve 459
# 459 error
# Reading lightcurve 460
# 460 error
# Reading lightcurve 461
# 461 error
# Reading lightcurve 462
# 462 error
# Reading lightcurve 463
# 463 error
# Reading lightcurve 464
# 464 error
# Reading lightcurve 465
# 465 error
# Reading lightcurve 466
# 466 error
# Reading lightcurve 467
# 467 error
# Reading lightcurve 468
# 468 error
# Reading lightcurve 469
# 469 error
# Reading lightcurve 470
# 470 error
# Reading lightcurve 471
# 471 error
# Reading lightcurve 472
# 472 error
# Reading lightcurve 473
# 473 error
# Reading lightcurve 474
# 474 error
# Reading lightcurve 475
# 475 error
# Reading lightcurve 476
# 476 error
# Reading lightcurve 477
# 477 error
# Reading lightcurve 478
# 478 error
# Reading lightcurve 479
# 479 error
# Reading lightcurve 480
# 480 error
# Reading lightcurve 481
# 481 error
# Reading lightcurve 482
# 482 error
# Reading lightcurve 483
# 483 error
# Reading lightcurve 484
# 484 error
# Reading lightcurve 485
# 485 error
# Reading lightcurve 486
# 486 error
# Reading lightcurve 487
# 487 error
# Reading lightcurve 488
# 488 error
# Reading lightcurve 489
# 489 error
# Reading lightcurve 490
# 490 error
# Reading lightcurve 491
# 491 error
# Reading lightcurve 492
# 492 error
# Reading lightcurve 493
# 493 error
# Reading lightcurve 494
# 494 error
# Reading lightcurve 495
# 495 error
# Reading lightcurve 496
# 496 error
# Reading lightcurve 497
# 497 error
# Reading lightcurve 498
# 498 error
# Reading lightcurve 499
# 499 error
# Reading lightcurve 500
# 500 error
# Reading lightcurve 501
# 501 error
# Reading lightcurve 502
# 502 error
# Reading lightcurve 503
# 503 error
# Reading lightcurve 504
# 504 error
# Reading lightcurve 505
# 505 error
# Reading lightcurve 506
# 506 error
# Reading lightcurve 507
# 507 error
# Reading lightcurve 508
# 508 error
# Reading lightcurve 509
# 509 error
# Reading lightcurve 510
# 510 error
# Reading lightcurve 511
# 511 error
# Reading lightcurve 512
# 512 error
# Reading lightcurve 513
# 513 error
# Reading lightcurve 514
# 514 error
# Reading lightcurve 515
# 515 error
# Reading lightcurve 516
# 516 error
# Reading lightcurve 517
# 517 error
# Reading lightcurve 518
# 518 error
# Reading lightcurve 519
# 519 error
# Reading lightcurve 520
# 520 error
# Reading lightcurve 521
# 521 error
# Reading lightcurve 522
# 522 error
# Reading lightcurve 523
# 523 error
# Reading lightcurve 524
# 524 error
# Reading lightcurve 525
# 525 error
# Reading lightcurve 526
# 526 error
# Reading lightcurve 527
# 527 error
# Reading lightcurve 528
# 528 error
# Reading lightcurve 529
# 529 error
# Reading lightcurve 530
# 530 error
# Reading lightcurve 531
# 531 error
# Reading lightcurve 532
# 532 error
# Reading lightcurve 533
# 533 error
# Reading lightcurve 534
# 534 error
# Reading lightcurve 535
# 535 error
# Reading lightcurve 536
# 536 error
# Reading lightcurve 537
# 537 error
# Reading lightcurve 538
# 538 error
# Reading lightcurve 539
# 539 error
# Reading lightcurve 540
# 540 error
# Reading lightcurve 541
# 541 error
# Reading lightcurve 542
# 542 error
# Reading lightcurve 543
# 543 error
# Reading lightcurve 544
# 544 error
# Reading lightcurve 545
# 545 error
# Reading lightcurve 546
# 546 error
# Reading lightcurve 547
# 547 error
# Reading lightcurve 548
# 548 error
# Reading lightcurve 549
# 549 error
# Reading lightcurve 550
# 550 error
# Reading lightcurve 551
# 551 error
# Reading lightcurve 552
# 552 error
# Reading lightcurve 553
# 553 error
# Reading lightcurve 554
# 554 error
# Reading lightcurve 555
# 555 error
# Reading lightcurve 556
# 556 error
# Reading lightcurve 557
# 557 error
# Reading lightcurve 558
# 558 error
# Reading lightcurve 559
# 559 error
# Reading lightcurve 560
# 560 error
# Reading lightcurve 561
# 561 error
# Reading lightcurve 562
# 562 error
# Reading lightcurve 563
# 563 error
# Reading lightcurve 564
# 564 error
# Reading lightcurve 565
# 565 error
# Reading lightcurve 566
# 566 error
# Reading lightcurve 567
# 567 error
# Reading lightcurve 568
# 568 error
# Reading lightcurve 569
# 569 error
# Reading lightcurve 570
# 570 error
# Reading lightcurve 571
# 571 error
# Reading lightcurve 572
# 572 error
# Reading lightcurve 573
# 573 error
# Reading lightcurve 574
# 574 error
# Reading lightcurve 575
# 575 error
# Reading lightcurve 576
# 576 error
# Reading lightcurve 577
# 577 error
# Reading lightcurve 578
# 578 error
# Reading lightcurve 579
# 579 error
# Reading lightcurve 580
# 580 error
# Reading lightcurve 581
# 581 error
# Reading lightcurve 582
# 582 error
# Reading lightcurve 583
# 583 error
# Reading lightcurve 584
# 584 error
# Reading lightcurve 585
# 585 error
# Reading lightcurve 586
# 586 error
# Reading lightcurve 587
# 587 error
# Reading lightcurve 588
# 588 error
# Reading lightcurve 589
# 589 error
# Reading lightcurve 590
# 590 error
# Reading lightcurve 591
# 591 error
# Reading lightcurve 592
# 592 error
# Reading lightcurve 593
# 593 error
# Reading lightcurve 594
# 594 error
# Reading lightcurve 595
# 595 error
# Reading lightcurve 596
# 596 error
# Reading lightcurve 597
# 597 error
# Reading lightcurve 598
# star, label, probability, flag
# 598 LPV_SRV_AGB_O 0.32 1
# Reading lightcurve 599
# 599 error
# Reading lightcurve 600
# 600 error
# Reading lightcurve 601
# 601 error
# Reading lightcurve 602
# 602 error
# Reading lightcurve 603
# 603 error
# Reading lightcurve 604
# 604 error
# Reading lightcurve 605
# 605 error
# Reading lightcurve 606
# 606 error
# Reading lightcurve 607
# 607 error
# Reading lightcurve 608
# 608 error
# Reading lightcurve 609
# 609 error
# Reading lightcurve 610
# 610 error
# Reading lightcurve 611
# 611 error
# Reading lightcurve 612
# 612 error
# Reading lightcurve 613
# 613 error
# Reading lightcurve 614
# 614 error
# Reading lightcurve 615
# 615 error
# Reading lightcurve 616
# 616 error
# Reading lightcurve 617
# 617 error
# Reading lightcurve 618
# 618 error
# Reading lightcurve 619
# 619 error
# Reading lightcurve 620
# 620 error
# Reading lightcurve 621
# 621 error
# Reading lightcurve 622
# 622 error
# Reading lightcurve 623
# 623 error
# Reading lightcurve 624
# 624 error
# Reading lightcurve 625
# 625 error
# Reading lightcurve 626
# 626 error
# Reading lightcurve 627
# 627 error
# Reading lightcurve 628
# 628 error
# Reading lightcurve 629
# 629 error
# Reading lightcurve 630
# 630 error
# Reading lightcurve 631
# 631 error
# Reading lightcurve 632
# 632 error
# Reading lightcurve 633
# 633 error
# Reading lightcurve 634
# 634 error
# Reading lightcurve 635
# 635 error
# Reading lightcurve 636
# 636 error
# Reading lightcurve 637
# 637 error
# Reading lightcurve 638
# 638 error
# Reading lightcurve 639
# 639 error
# Reading lightcurve 640
# 640 error
# Reading lightcurve 641
# 641 error
# Reading lightcurve 642
# 642 error
# Reading lightcurve 643
# 643 error
# Reading lightcurve 644
# 644 error
# Reading lightcurve 645
# 645 error
# Reading lightcurve 646
# 646 error
# Reading lightcurve 647
# 647 error
# Reading lightcurve 648
# 648 error
# Reading lightcurve 649
# 649 error
# Reading lightcurve 650
# 650 error
# Reading lightcurve 651
# 651 error
# Reading lightcurve 652
# 652 error
# Reading lightcurve 653
# 653 error
# Reading lightcurve 654
# 654 error
# Reading lightcurve 655
# 655 error
# Reading lightcurve 656
# 656 error
# Reading lightcurve 657
# 657 error
# Reading lightcurve 658
# 658 error
# Reading lightcurve 659
# 659 error
# Reading lightcurve 660
# 660 error
# Reading lightcurve 661
# 661 error
# Reading lightcurve 662
# 662 error
# Reading lightcurve 663
# 663 error
# Reading lightcurve 664
# 664 error
# Reading lightcurve 665
# 665 error
# Reading lightcurve 666
# 666 error
# Reading lightcurve 667
# 667 error
# Reading lightcurve 668
# 668 error
# Reading lightcurve 669
# 669 error
# Reading lightcurve 670
# 670 error
# Reading lightcurve 671
# 671 error
# Reading lightcurve 672
# 672 error
# Reading lightcurve 673
# 673 error
# Reading lightcurve 674
# 674 error
# Reading lightcurve 675
# 675 error
# Reading lightcurve 676
# 676 error
# Reading lightcurve 677
# 677 error
# Reading lightcurve 678
# 678 error
# Reading lightcurve 679
# 679 error
# Reading lightcurve 680
# 680 error
# Reading lightcurve 681
# 681 error
# Reading lightcurve 682
# 682 error
# Reading lightcurve 683
# 683 error
# Reading lightcurve 684
# 684 error
# Reading lightcurve 685
# 685 error
# Reading lightcurve 686
# 686 error
# Reading lightcurve 687
# 687 error
# Reading lightcurve 688
# 688 error
# Reading lightcurve 689
# 689 error
# Reading lightcurve 690
# 690 error
# Reading lightcurve 691
# 691 error
# Reading lightcurve 692
# 692 error
# Reading lightcurve 693
# 693 error
# Reading lightcurve 694
# 694 error
# Reading lightcurve 695
# 695 error
# Reading lightcurve 696
# 696 error
# Reading lightcurve 697
# 697 error
# Reading lightcurve 698
# 698 error
# Reading lightcurve 699
# 699 error
# Reading lightcurve 700
# 700 error
# Reading lightcurve 701
# 701 error
# Reading lightcurve 702
# 702 error
# Reading lightcurve 703
# 703 error
# Reading lightcurve 704
# 704 error
# Reading lightcurve 705
# 705 error
# Reading lightcurve 706
# 706 error
# Reading lightcurve 707
# 707 error
# Reading lightcurve 708
# 708 error
# Reading lightcurve 709
# 709 error
# Reading lightcurve 710
# 710 error
# Reading lightcurve 711
# 711 error
# Reading lightcurve 712
# 712 error
# Reading lightcurve 713
# 713 error
# Reading lightcurve 714
# 714 error
# Reading lightcurve 715
# 715 error
# Reading lightcurve 716
# 716 error
# Reading lightcurve 717
# 717 error
# Reading lightcurve 718
# 718 error
# Reading lightcurve 719
# 719 error
# Reading lightcurve 720
# 720 error
# Reading lightcurve 721
# 721 error
# Reading lightcurve 722
# 722 error
# Reading lightcurve 723
# 723 error
# Reading lightcurve 724
# 724 error
# Reading lightcurve 725
# 725 error
# Reading lightcurve 726
# 726 error
# Reading lightcurve 727
# 727 error
# Reading lightcurve 728
# 728 error
# Reading lightcurve 729
# 729 error
# Reading lightcurve 730
# 730 error
# Reading lightcurve 731
# 731 error
# Reading lightcurve 732
# 732 error
# Reading lightcurve 733
# 733 error
# Reading lightcurve 734
# 734 error
# Reading lightcurve 735
# 735 error
# Reading lightcurve 736
# 736 error
# Reading lightcurve 737
# 737 error
# Reading lightcurve 738
# 738 error
# Reading lightcurve 739
# 739 error
# Reading lightcurve 740
# 740 error
# Reading lightcurve 741
# 741 error
# Reading lightcurve 742
# 742 error
# Reading lightcurve 743
# 743 error
# Reading lightcurve 744
# 744 error
# Reading lightcurve 745
# 745 error
# Reading lightcurve 746
# 746 error
# Reading lightcurve 747
# 747 error
# Reading lightcurve 748
# 748 error
# Reading lightcurve 749
# 749 error
# Reading lightcurve 750
# 750 error
# Reading lightcurve 751
# 751 error
# Reading lightcurve 752
# 752 error
# Reading lightcurve 753
# 753 error
# Reading lightcurve 754
# 754 error
# Reading lightcurve 755
# 755 error
# Reading lightcurve 756
# 756 error
# Reading lightcurve 757
# 757 error
# Reading lightcurve 758
# 758 error
# Reading lightcurve 759
# 759 error
# Reading lightcurve 760
# 760 error
# Reading lightcurve 761
# 761 error
# Reading lightcurve 762
# 762 error
# Reading lightcurve 763
# 763 error
# Reading lightcurve 764
# 764 error
# Reading lightcurve 765
# 765 error
# Reading lightcurve 766
# 766 error
# Reading lightcurve 767
# 767 error
# Reading lightcurve 768
# 768 error
# Reading lightcurve 769
# 769 error
# Reading lightcurve 770
# 770 error
# Reading lightcurve 771
# 771 error
# Reading lightcurve 772
# 772 error
# Reading lightcurve 773
# 773 error
# Reading lightcurve 774
# 774 error
# Reading lightcurve 775
# 775 error
# Reading lightcurve 776
# 776 error
# Reading lightcurve 777
# 777 error
# Reading lightcurve 778
# 778 error
# Reading lightcurve 779
# 779 error
# Reading lightcurve 780
# 780 error
# Reading lightcurve 781
# 781 error
# Reading lightcurve 782
# 782 error
# Reading lightcurve 783
# 783 error
# Reading lightcurve 784
# 784 error
# Reading lightcurve 785
# 785 error
# Reading lightcurve 786
# 786 error
# Reading lightcurve 787
# 787 error
# Reading lightcurve 788
# 788 error
# Reading lightcurve 789
# 789 error
# Reading lightcurve 790
# 790 error
# Reading lightcurve 791
# 791 error
# Reading lightcurve 792
# 792 error
# Reading lightcurve 793
# 793 error
# Reading lightcurve 794
# 794 error
# Reading lightcurve 795
# 795 error
# Reading lightcurve 796
# 796 error
# Reading lightcurve 797
# 797 error
# Reading lightcurve 798
# 798 error
# Reading lightcurve 799
# 799 error
# Reading lightcurve 800
# 800 error
# Reading lightcurve 801
# 801 error
# Reading lightcurve 802
# 802 error
# Reading lightcurve 803
# 803 error
# Reading lightcurve 804
# 804 error
# Reading lightcurve 805
# 805 error
# Reading lightcurve 806
# 806 error
# Reading lightcurve 807
# 807 error
# Reading lightcurve 808
# 808 error
# Reading lightcurve 809
# 809 error
# Reading lightcurve 810
# 810 error
# Reading lightcurve 811
# 811 error
# Reading lightcurve 812
# 812 error
# Reading lightcurve 813
# 813 error
# Reading lightcurve 814
# 814 error
# Reading lightcurve 815
# 815 error
# Reading lightcurve 816
# 816 error
# Reading lightcurve 817
# 817 error
# Reading lightcurve 818
# 818 error
# Reading lightcurve 819
# 819 error
# Reading lightcurve 820
# 820 error
# Reading lightcurve 821
# 821 error
# Reading lightcurve 822
# 822 error
# Reading lightcurve 823
# 823 error
# Reading lightcurve 824
# 824 error
# Reading lightcurve 825
# 825 error
# Reading lightcurve 826
# 826 error
# Reading lightcurve 827
# 827 error
# Reading lightcurve 828
# 828 error
# Reading lightcurve 829
# 829 error
# Reading lightcurve 830
# 830 error
# Reading lightcurve 831
# 831 error
# Reading lightcurve 832
# 832 error
# Reading lightcurve 833
# 833 error
# Reading lightcurve 834
# 834 error
# Reading lightcurve 835
# 835 error
# Reading lightcurve 836
# 836 error
# Reading lightcurve 837
# 837 error
# Reading lightcurve 838
# 838 error
# Reading lightcurve 839
# 839 error
# Reading lightcurve 840
# 840 error
# Reading lightcurve 841
# 841 error
# Reading lightcurve 842
# 842 error
# Reading lightcurve 843
# 843 error
# Reading lightcurve 844
# 844 error
# Reading lightcurve 845
# 845 error
# Reading lightcurve 846
# 846 error
# Reading lightcurve 847
# 847 error
# Reading lightcurve 848
# 848 error
# Reading lightcurve 849
# 849 error
# Reading lightcurve 850
# 850 error
# Reading lightcurve 851
# 851 error
# Reading lightcurve 852
# 852 error
# Reading lightcurve 853
# 853 error
# Reading lightcurve 854
# 854 error
# Reading lightcurve 855
# 855 error
# Reading lightcurve 856
# 856 error
# Reading lightcurve 857
# 857 error
# Reading lightcurve 858
# 858 error
# Reading lightcurve 859
# 859 error
# Reading lightcurve 860
# 860 error
# Reading lightcurve 861
# 861 error
# Reading lightcurve 862
# 862 error
# Reading lightcurve 863
# 863 error
# Reading lightcurve 864
# 864 error
# Reading lightcurve 865
# 865 error
# Reading lightcurve 866
# 866 error
# Reading lightcurve 867
# 867 error
# Reading lightcurve 868
# 868 error
# Reading lightcurve 869
# 869 error
# Reading lightcurve 870
# 870 error
# Reading lightcurve 871
# 871 error
# Reading lightcurve 872
# 872 error
# Reading lightcurve 873
# 873 error
# Reading lightcurve 874
# 874 error
# Reading lightcurve 875
# 875 error
# Reading lightcurve 876
# 876 error
# Reading lightcurve 877
# 877 error
# Reading lightcurve 878
# 878 error
# Reading lightcurve 879
# 879 error
# Reading lightcurve 880
# 880 error
# Reading lightcurve 881
# 881 error
# Reading lightcurve 882
# 882 error
# Reading lightcurve 883
# 883 error
# Reading lightcurve 884
# 884 error
# Reading lightcurve 885
# 885 error
# Reading lightcurve 886
# 886 error
# Reading lightcurve 887
# 887 error
# Reading lightcurve 888
# 888 error
# Reading lightcurve 889
# 889 error
# Reading lightcurve 890
# 890 error
# Reading lightcurve 891
# 891 error
# Reading lightcurve 892
# 892 error
# Reading lightcurve 893
# 893 error
# Reading lightcurve 894
# 894 error
# Reading lightcurve 895
# 895 error
# Reading lightcurve 896
# 896 error
# Reading lightcurve 897
# 897 error
# Reading lightcurve 898
# 898 error
# Reading lightcurve 899
# 899 error
# Reading lightcurve 900
# 900 error
# Reading lightcurve 901
# 901 error
# Reading lightcurve 902
# 902 error
# Reading lightcurve 903
# 903 error
# Reading lightcurve 904
# 904 error
# Reading lightcurve 905
# 905 error
# Reading lightcurve 906
# 906 error
# Reading lightcurve 907
# 907 error
# Reading lightcurve 908
# 908 error
# Reading lightcurve 909
# 909 error
# Reading lightcurve 910
# 910 error
# Reading lightcurve 911
# 911 error
# Reading lightcurve 912
# 912 error
# Reading lightcurve 913
# 913 error
# Reading lightcurve 914
# 914 error
# Reading lightcurve 915
# 915 error
# Reading lightcurve 916
# 916 error
# Reading lightcurve 917
# 917 error
# Reading lightcurve 918
# 918 error
# Reading lightcurve 919
# 919 error
# Reading lightcurve 920
# 920 error
# Reading lightcurve 921
# 921 error
# Reading lightcurve 922
# 922 error
# Reading lightcurve 923
# 923 error
# Reading lightcurve 924
# 924 error
# Reading lightcurve 925
# 925 error
# Reading lightcurve 926
# 926 error
# Reading lightcurve 927
# 927 error
# Reading lightcurve 928
# 928 error
# Reading lightcurve 929
# 929 error
# Reading lightcurve 930
# 930 error
# Reading lightcurve 931
# 931 error
# Reading lightcurve 932
# 932 error
# Reading lightcurve 933
# 933 error
# Reading lightcurve 934
# 934 error
# Reading lightcurve 935
# 935 error
# Reading lightcurve 936
# 936 error
# Reading lightcurve 937
# 937 error
# Reading lightcurve 938
# 938 error
# Reading lightcurve 939
# 939 error
# Reading lightcurve 940
# 940 error
# Reading lightcurve 941
# 941 error
# Reading lightcurve 942
# 942 error
# Reading lightcurve 943
# 943 error
# Reading lightcurve 944
# 944 error
# Reading lightcurve 945
# 945 error
# Reading lightcurve 946
# 946 error
# Reading lightcurve 947
# 947 error
# Reading lightcurve 948
# 948 error
# Reading lightcurve 949
# 949 error
# Reading lightcurve 950
# 950 error
# Reading lightcurve 951
# 951 error
# Reading lightcurve 952
# 952 error
# Reading lightcurve 953
# 953 error
# Reading lightcurve 954
# 954 error
# Reading lightcurve 955
# 955 error
# Reading lightcurve 956
# 956 error
# Reading lightcurve 957
# 957 error
# Reading lightcurve 958
# 958 error
# Reading lightcurve 959
# 959 error
# Reading lightcurve 960
# 960 error
# Reading lightcurve 961
# 961 error
# Reading lightcurve 962
# 962 error
# Reading lightcurve 963
# 963 error
# Reading lightcurve 964
# 964 error
# Reading lightcurve 965
# 965 error
# Reading lightcurve 966
# 966 error
# Reading lightcurve 967
# 967 error
# Reading lightcurve 968
# 968 error
# Reading lightcurve 969
# 969 error
# Reading lightcurve 970
# 970 error
# Reading lightcurve 971
# 971 error
# Reading lightcurve 972
# 972 error
# Reading lightcurve 973
# 973 error
# Reading lightcurve 974
# 974 error
# Reading lightcurve 975
# 975 error
# Reading lightcurve 976
# 976 error
# Reading lightcurve 977
# 977 error
# Reading lightcurve 978
# 978 error
# Reading lightcurve 979
# 979 error
# Reading lightcurve 980
# 980 error
# Reading lightcurve 981
# 981 error
# Reading lightcurve 982
# 982 error
# Reading lightcurve 983
# 983 error
# Reading lightcurve 984
# 984 error
# Reading lightcurve 985
# 985 error
# Reading lightcurve 986
# 986 error
# Reading lightcurve 987
# 987 error
# Reading lightcurve 988
# 988 error
# Reading lightcurve 989
# 989 error
# Reading lightcurve 990
# 990 error
# Reading lightcurve 991
# 991 error
# Reading lightcurve 992
# 992 error
# Reading lightcurve 993
# 993 error
# Reading lightcurve 994
# 994 error
# Reading lightcurve 995
# 995 error
# Reading lightcurve 996
# 996 error
# Reading lightcurve 997
# 997 error
# Reading lightcurve 998
# 998 error
# Reading lightcurve 999
# 999 error
# /opt/conda/lib/python3.5/site-packages/upsilon-1.2.4-py3.5.egg/upsilon/extract_features/extract_features.py:61: UserWarning: The number of data points are less than 80.
#   % min_n_data)
