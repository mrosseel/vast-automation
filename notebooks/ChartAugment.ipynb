# %%
import os
os.chdir('/home/jovyan/work')
import do_calibration
import reading
import init

# %%
candidates = do_calibration.get_candidates(0)

# %%
candidates_hash = {}
for entry in candidates:
    candidates_hash[entry.local_id] = entry

# %%
def upsilonify_path(the_path):
    the_dir = os.listdir(the_path)
    the_dir.sort()
    results = {}
    for name in the_dir: # 'file' is a builtin type, 'name' is a less-ambiguous variable name.
        upsilon_entry = candidates_hash.get(reading.filename_to_star(name), None)
        if upsilon_entry is None:
            print("Skipping", name)
            continue
        #print(upsilon_entry.upsilon)
        new_name = "{}_{:.2f}_{}".format(upsilon_entry.upsilon[2], upsilon_entry.upsilon[1], name)
        print("Renaming {} to {}".format(name, new_name))
        os.rename(the_path+name, the_path+new_name)

def undo_upsilonify_path(the_path):
    the_dir = os.listdir(the_path)
    the_dir.sort()
    results = {}
    for name in the_dir: # 'file' is a builtin type, 'name' is a less-ambiguous variable name.
        new_name = name[7:]
        print("Renaming {} to {}".format(name, new_name))
        os.rename(the_path+name, the_path+new_name)

upsilonify_path(init.phasedir)
#undo_upsilonify_path(init.phasedir)
# Out:
# Renaming phase00001a.png to 0_0.19_phase00001a.png
# Renaming phase00001b.png to 0_0.19_phase00001b.png
# Renaming phase00002a.png to 0_0.50_phase00002a.png
# Renaming phase00002b.png to 0_0.50_phase00002b.png
# Renaming phase00003a.png to 1_0.50_phase00003a.png
# Renaming phase00003b.png to 1_0.50_phase00003b.png
# Renaming phase00004a.png to 0_0.20_phase00004a.png
# Renaming phase00004b.png to 0_0.20_phase00004b.png
# Renaming phase00005a.png to 1_0.38_phase00005a.png
# Renaming phase00005b.png to 1_0.38_phase00005b.png
# Renaming phase00006a.png to 1_0.48_phase00006a.png
# Renaming phase00006b.png to 1_0.48_phase00006b.png
# Renaming phase00007a.png to 1_0.34_phase00007a.png
# Renaming phase00007b.png to 1_0.34_phase00007b.png
# Renaming phase00008a.png to 1_0.60_phase00008a.png
# Renaming phase00008b.png to 1_0.60_phase00008b.png
# Renaming phase00009a.png to 1_0.44_phase00009a.png
# Renaming phase00009b.png to 1_0.44_phase00009b.png
# Renaming phase00010a.png to 1_0.47_phase00010a.png
# Renaming phase00010b.png to 1_0.47_phase00010b.png
# Renaming phase00011a.png to 0_0.28_phase00011a.png
# Renaming phase00011b.png to 0_0.28_phase00011b.png
# Renaming phase00012a.png to 1_0.30_phase00012a.png
# Renaming phase00012b.png to 1_0.30_phase00012b.png
# Renaming phase00013a.png to 1_0.49_phase00013a.png
# Renaming phase00013b.png to 1_0.49_phase00013b.png
# Renaming phase00014a.png to 0_0.21_phase00014a.png
# Renaming phase00014b.png to 0_0.21_phase00014b.png
# Renaming phase00015a.png to 1_0.35_phase00015a.png
# Renaming phase00015b.png to 1_0.35_phase00015b.png
# Renaming phase00016a.png to 0_0.22_phase00016a.png
# Renaming phase00016b.png to 0_0.22_phase00016b.png
# Renaming phase00018a.png to 1_0.48_phase00018a.png
# Renaming phase00018b.png to 1_0.48_phase00018b.png
# Renaming phase00019a.png to 1_0.38_phase00019a.png
# Renaming phase00019b.png to 1_0.38_phase00019b.png
# Renaming phase00020a.png to 1_0.44_phase00020a.png
# Renaming phase00020b.png to 1_0.44_phase00020b.png
# Renaming phase00021a.png to 1_0.52_phase00021a.png
# Renaming phase00021b.png to 1_0.52_phase00021b.png
# Renaming phase00023a.png to 1_0.56_phase00023a.png
# Renaming phase00023b.png to 1_0.56_phase00023b.png
# Renaming phase00024a.png to 0_0.22_phase00024a.png
# Renaming phase00024b.png to 0_0.22_phase00024b.png
# Renaming phase00025a.png to 1_0.43_phase00025a.png
# Renaming phase00025b.png to 1_0.43_phase00025b.png
# Renaming phase00026a.png to 0_0.27_phase00026a.png
# Renaming phase00026b.png to 0_0.27_phase00026b.png
# Renaming phase00029a.png to 0_0.25_phase00029a.png
# Renaming phase00029b.png to 0_0.25_phase00029b.png
# Renaming phase00030a.png to 1_0.46_phase00030a.png
# Renaming phase00030b.png to 1_0.46_phase00030b.png
# Renaming phase00031a.png to 1_0.31_phase00031a.png
# Renaming phase00031b.png to 1_0.31_phase00031b.png
# Renaming phase00032a.png to 0_0.29_phase00032a.png
# Renaming phase00032b.png to 0_0.29_phase00032b.png
# Renaming phase00033a.png to 1_0.48_phase00033a.png
# Renaming phase00033b.png to 1_0.48_phase00033b.png
# Renaming phase00034a.png to 1_0.76_phase00034a.png
# Renaming phase00034b.png to 1_0.76_phase00034b.png
# Renaming phase00036a.png to 1_0.80_phase00036a.png
# Renaming phase00036b.png to 1_0.80_phase00036b.png
# Renaming phase00037a.png to 0_0.33_phase00037a.png
# Renaming phase00037b.png to 0_0.33_phase00037b.png
# Renaming phase00038a.png to 1_0.66_phase00038a.png
# Renaming phase00038b.png to 1_0.66_phase00038b.png
# Renaming phase00039a.png to 1_0.50_phase00039a.png
# Renaming phase00039b.png to 1_0.50_phase00039b.png
# Renaming phase00040a.png to 1_0.45_phase00040a.png
# Renaming phase00040b.png to 1_0.45_phase00040b.png
# Renaming phase00041a.png to 0_0.53_phase00041a.png
# Renaming phase00041b.png to 0_0.53_phase00041b.png
# Renaming phase00042a.png to 0_0.70_phase00042a.png
# Renaming phase00042b.png to 0_0.70_phase00042b.png
# Renaming phase00043a.png to 0_0.23_phase00043a.png
# Renaming phase00043b.png to 0_0.23_phase00043b.png
# Renaming phase00044a.png to 1_0.67_phase00044a.png
# Renaming phase00044b.png to 1_0.67_phase00044b.png
# Renaming phase00045a.png to 1_0.28_phase00045a.png
# Renaming phase00045b.png to 1_0.28_phase00045b.png
# Renaming phase00046a.png to 1_0.81_phase00046a.png
# Renaming phase00046b.png to 1_0.81_phase00046b.png
# Renaming phase00047a.png to 1_0.60_phase00047a.png
# Renaming phase00047b.png to 1_0.60_phase00047b.png
# Renaming phase00048a.png to 1_0.83_phase00048a.png
# Renaming phase00048b.png to 1_0.83_phase00048b.png
# Renaming phase00049a.png to 1_0.33_phase00049a.png
# Renaming phase00049b.png to 1_0.33_phase00049b.png
# Renaming phase00050a.png to 0_0.30_phase00050a.png
# Renaming phase00050b.png to 0_0.30_phase00050b.png
# Renaming phase00051a.png to 1_0.91_phase00051a.png
# Renaming phase00051b.png to 1_0.91_phase00051b.png
# Renaming phase00052a.png to 1_0.49_phase00052a.png
# Renaming phase00052b.png to 1_0.49_phase00052b.png
# Renaming phase00054a.png to 1_0.78_phase00054a.png
# Renaming phase00054b.png to 1_0.78_phase00054b.png
# Renaming phase00055a.png to 1_0.70_phase00055a.png
# Renaming phase00055b.png to 1_0.70_phase00055b.png
# Renaming phase00056a.png to 1_0.63_phase00056a.png
# Renaming phase00056b.png to 1_0.63_phase00056b.png
# Renaming phase00057a.png to 1_0.57_phase00057a.png
# Renaming phase00057b.png to 1_0.57_phase00057b.png
# Renaming phase00058a.png to 1_0.80_phase00058a.png
# Renaming phase00058b.png to 1_0.80_phase00058b.png
# Renaming phase00059a.png to 1_0.47_phase00059a.png
# Renaming phase00059b.png to 1_0.47_phase00059b.png
# Renaming phase00061a.png to 1_0.31_phase00061a.png
# Renaming phase00061b.png to 1_0.31_phase00061b.png
# Renaming phase00062a.png to 1_0.36_phase00062a.png
# Renaming phase00062b.png to 1_0.36_phase00062b.png
# Renaming phase00063a.png to 1_0.45_phase00063a.png
# Renaming phase00063b.png to 1_0.45_phase00063b.png
# Renaming phase00064a.png to 1_0.43_phase00064a.png
# Renaming phase00064b.png to 1_0.43_phase00064b.png
# Renaming phase00065a.png to 1_0.74_phase00065a.png
# Renaming phase00065b.png to 1_0.74_phase00065b.png
# Renaming phase00066a.png to 1_0.65_phase00066a.png
# Renaming phase00066b.png to 1_0.65_phase00066b.png
# Renaming phase00067a.png to 0_0.19_phase00067a.png
# Renaming phase00067b.png to 0_0.19_phase00067b.png
# Renaming phase00068a.png to 0_0.29_phase00068a.png
# Renaming phase00068b.png to 0_0.29_phase00068b.png
# Renaming phase00069a.png to 0_0.40_phase00069a.png
# Renaming phase00069b.png to 0_0.40_phase00069b.png
# Renaming phase00070a.png to 1_0.46_phase00070a.png
# Renaming phase00070b.png to 1_0.46_phase00070b.png
# Renaming phase00071a.png to 1_0.28_phase00071a.png
# Renaming phase00071b.png to 1_0.28_phase00071b.png
# Renaming phase00072a.png to 1_0.75_phase00072a.png
# Renaming phase00072b.png to 1_0.75_phase00072b.png
# Renaming phase00073a.png to 1_0.55_phase00073a.png
# Renaming phase00073b.png to 1_0.55_phase00073b.png
# Renaming phase00074a.png to 1_0.71_phase00074a.png
# Renaming phase00074b.png to 1_0.71_phase00074b.png
# Renaming phase00075a.png to 1_0.73_phase00075a.png
# Renaming phase00075b.png to 1_0.73_phase00075b.png
# Renaming phase00076a.png to 1_0.74_phase00076a.png
# Renaming phase00076b.png to 1_0.74_phase00076b.png
# Renaming phase00077a.png to 0_0.34_phase00077a.png
# Renaming phase00077b.png to 0_0.34_phase00077b.png
# Renaming phase00079a.png to 1_0.41_phase00079a.png
# Renaming phase00079b.png to 1_0.41_phase00079b.png
# Renaming phase00080a.png to 1_0.50_phase00080a.png
# Renaming phase00080b.png to 1_0.50_phase00080b.png
# Renaming phase00081a.png to 1_0.62_phase00081a.png
# Renaming phase00081b.png to 1_0.62_phase00081b.png
# Renaming phase00082a.png to 0_0.29_phase00082a.png
# Renaming phase00082b.png to 0_0.29_phase00082b.png
# Renaming phase00083a.png to 1_0.40_phase00083a.png
# Renaming phase00083b.png to 1_0.40_phase00083b.png
# Renaming phase00084a.png to 0_0.34_phase00084a.png
# Renaming phase00084b.png to 0_0.34_phase00084b.png
# Renaming phase00085a.png to 1_0.24_phase00085a.png
# Renaming phase00085b.png to 1_0.24_phase00085b.png
# Renaming phase00086a.png to 0_0.25_phase00086a.png
# Renaming phase00086b.png to 0_0.25_phase00086b.png
# Renaming phase00087a.png to 1_0.44_phase00087a.png
# Renaming phase00087b.png to 1_0.44_phase00087b.png
# Renaming phase00088a.png to 1_0.36_phase00088a.png
# Renaming phase00088b.png to 1_0.36_phase00088b.png
# Renaming phase00089a.png to 1_0.69_phase00089a.png
# Renaming phase00089b.png to 1_0.69_phase00089b.png
# Renaming phase00090a.png to 1_0.75_phase00090a.png
# Renaming phase00090b.png to 1_0.75_phase00090b.png
# Renaming phase00091a.png to 1_0.48_phase00091a.png
# Renaming phase00091b.png to 1_0.48_phase00091b.png
# Renaming phase00092a.png to 1_0.75_phase00092a.png
# Renaming phase00092b.png to 1_0.75_phase00092b.png
# Renaming phase00093a.png to 0_0.33_phase00093a.png
# Renaming phase00093b.png to 0_0.33_phase00093b.png
# Renaming phase00094a.png to 1_0.45_phase00094a.png
# Renaming phase00094b.png to 1_0.45_phase00094b.png
# Renaming phase00095a.png to 1_0.43_phase00095a.png
# Renaming phase00095b.png to 1_0.43_phase00095b.png
# Renaming phase00096a.png to 0_0.55_phase00096a.png
# Renaming phase00096b.png to 0_0.55_phase00096b.png
# Renaming phase00097a.png to 1_0.53_phase00097a.png
# Renaming phase00097b.png to 1_0.53_phase00097b.png
# Renaming phase00098a.png to 1_0.38_phase00098a.png
# Renaming phase00098b.png to 1_0.38_phase00098b.png
# Renaming phase00099a.png to 1_0.35_phase00099a.png
# Renaming phase00099b.png to 1_0.35_phase00099b.png
# Renaming phase00100a.png to 1_0.51_phase00100a.png
# Renaming phase00100b.png to 1_0.51_phase00100b.png
# Renaming phase00105a.png to 1_0.54_phase00105a.png
# Renaming phase00105b.png to 1_0.54_phase00105b.png
# Renaming phase00106a.png to 0_0.61_phase00106a.png
# Renaming phase00106b.png to 0_0.61_phase00106b.png
# Renaming phase00107a.png to 0_0.37_phase00107a.png
# Renaming phase00107b.png to 0_0.37_phase00107b.png
# Renaming phase00108a.png to 1_0.69_phase00108a.png
# Renaming phase00108b.png to 1_0.69_phase00108b.png
# Renaming phase00109a.png to 1_0.52_phase00109a.png
# Renaming phase00109b.png to 1_0.52_phase00109b.png
# Renaming phase00110a.png to 1_0.64_phase00110a.png
# Renaming phase00110b.png to 1_0.64_phase00110b.png
# Renaming phase00111a.png to 1_0.68_phase00111a.png
# Renaming phase00111b.png to 1_0.68_phase00111b.png
# Renaming phase00112a.png to 1_0.77_phase00112a.png
# Renaming phase00112b.png to 1_0.77_phase00112b.png
# Renaming phase00114a.png to 1_0.49_phase00114a.png
# Renaming phase00114b.png to 1_0.49_phase00114b.png
# Renaming phase00116a.png to 0_0.32_phase00116a.png
# Renaming phase00116b.png to 0_0.32_phase00116b.png
# Renaming phase00117a.png to 0_0.26_phase00117a.png
# Renaming phase00117b.png to 0_0.26_phase00117b.png
# Renaming phase00118a.png to 0_0.30_phase00118a.png
# Renaming phase00118b.png to 0_0.30_phase00118b.png
# Renaming phase00119a.png to 1_0.36_phase00119a.png
# Renaming phase00119b.png to 1_0.36_phase00119b.png
# Renaming phase00120a.png to 1_0.41_phase00120a.png
# Renaming phase00120b.png to 1_0.41_phase00120b.png
# Renaming phase00121a.png to 1_0.31_phase00121a.png
# Renaming phase00121b.png to 1_0.31_phase00121b.png
# Renaming phase00122a.png to 1_0.75_phase00122a.png
# Renaming phase00122b.png to 1_0.75_phase00122b.png
# Renaming phase00123a.png to 0_0.20_phase00123a.png
# Renaming phase00123b.png to 0_0.20_phase00123b.png
# Renaming phase00124a.png to 1_0.46_phase00124a.png
# Renaming phase00124b.png to 1_0.46_phase00124b.png
# Renaming phase00125a.png to 1_0.65_phase00125a.png
# Renaming phase00125b.png to 1_0.65_phase00125b.png
# Renaming phase00126a.png to 1_0.34_phase00126a.png
# Renaming phase00126b.png to 1_0.34_phase00126b.png
# Renaming phase00127a.png to 1_0.66_phase00127a.png
# Renaming phase00127b.png to 1_0.66_phase00127b.png
# Renaming phase00128a.png to 0_0.33_phase00128a.png
# Renaming phase00128b.png to 0_0.33_phase00128b.png
# Renaming phase00129a.png to 1_0.44_phase00129a.png
# Renaming phase00129b.png to 1_0.44_phase00129b.png
# Renaming phase00130a.png to 1_0.63_phase00130a.png
# Renaming phase00130b.png to 1_0.63_phase00130b.png
# Renaming phase00132a.png to 1_0.51_phase00132a.png
# Renaming phase00132b.png to 1_0.51_phase00132b.png
# Renaming phase00133a.png to 0_0.79_phase00133a.png
# Renaming phase00133b.png to 0_0.79_phase00133b.png
# Renaming phase00134a.png to 0_0.29_phase00134a.png
# Renaming phase00134b.png to 0_0.29_phase00134b.png
# Renaming phase00135a.png to 0_0.21_phase00135a.png
# Renaming phase00135b.png to 0_0.21_phase00135b.png
# Renaming phase00136a.png to 0_0.84_phase00136a.png
# Renaming phase00136b.png to 0_0.84_phase00136b.png
# Renaming phase00137a.png to 1_0.56_phase00137a.png
# Renaming phase00137b.png to 1_0.56_phase00137b.png
# Renaming phase00138a.png to 0_0.99_phase00138a.png
# Renaming phase00138b.png to 0_0.99_phase00138b.png
# Renaming phase00139a.png to 0_0.24_phase00139a.png
# Renaming phase00139b.png to 0_0.24_phase00139b.png
# Renaming phase00140a.png to 1_0.54_phase00140a.png
# Renaming phase00140b.png to 1_0.54_phase00140b.png
# Renaming phase00141a.png to 0_0.70_phase00141a.png
# Renaming phase00141b.png to 0_0.70_phase00141b.png
# Renaming phase00142a.png to 1_0.37_phase00142a.png
# Renaming phase00142b.png to 1_0.37_phase00142b.png
# Renaming phase00143a.png to 1_0.69_phase00143a.png
# Renaming phase00143b.png to 1_0.69_phase00143b.png
# Renaming phase00144a.png to 0_0.17_phase00144a.png
# Renaming phase00144b.png to 0_0.17_phase00144b.png
# Renaming phase00145a.png to 1_0.58_phase00145a.png
# Renaming phase00145b.png to 1_0.58_phase00145b.png
# Renaming phase00147a.png to 0_0.56_phase00147a.png
# Renaming phase00147b.png to 0_0.56_phase00147b.png
# Renaming phase00148a.png to 1_0.33_phase00148a.png
# Renaming phase00148b.png to 1_0.33_phase00148b.png
# Renaming phase00149a.png to 1_0.77_phase00149a.png
# Renaming phase00149b.png to 1_0.77_phase00149b.png
# Renaming phase00150a.png to 1_0.57_phase00150a.png
# Renaming phase00150b.png to 1_0.57_phase00150b.png
# Renaming phase00151a.png to 0_0.29_phase00151a.png
# Renaming phase00151b.png to 0_0.29_phase00151b.png
# Renaming phase00152a.png to 1_0.47_phase00152a.png
# Renaming phase00152b.png to 1_0.47_phase00152b.png
# Renaming phase00153a.png to 1_0.60_phase00153a.png
# Renaming phase00153b.png to 1_0.60_phase00153b.png
# Renaming phase00154a.png to 1_0.83_phase00154a.png
# Renaming phase00154b.png to 1_0.83_phase00154b.png
# Renaming phase00155a.png to 0_0.23_phase00155a.png
# Renaming phase00155b.png to 0_0.23_phase00155b.png
# Renaming phase00156a.png to 0_0.19_phase00156a.png
# Renaming phase00156b.png to 0_0.19_phase00156b.png
# Renaming phase00157a.png to 1_0.30_phase00157a.png
# Renaming phase00157b.png to 1_0.30_phase00157b.png
# Renaming phase00158a.png to 1_0.60_phase00158a.png
# Renaming phase00158b.png to 1_0.60_phase00158b.png
# Renaming phase00159a.png to 1_0.73_phase00159a.png
# Renaming phase00159b.png to 1_0.73_phase00159b.png
# Renaming phase00160a.png to 0_0.25_phase00160a.png
# Renaming phase00160b.png to 0_0.25_phase00160b.png
# Renaming phase00161a.png to 1_0.27_phase00161a.png
# Renaming phase00161b.png to 1_0.27_phase00161b.png
# Renaming phase00162a.png to 0_0.48_phase00162a.png
# Renaming phase00162b.png to 0_0.48_phase00162b.png
# Renaming phase00163a.png to 1_0.69_phase00163a.png
# Renaming phase00163b.png to 1_0.69_phase00163b.png
# Renaming phase00164a.png to 1_0.72_phase00164a.png
# Renaming phase00164b.png to 1_0.72_phase00164b.png
# Renaming phase00165a.png to 1_0.51_phase00165a.png
# Renaming phase00165b.png to 1_0.51_phase00165b.png
# Renaming phase00166a.png to 1_0.65_phase00166a.png
# Renaming phase00166b.png to 1_0.65_phase00166b.png
# Renaming phase00167a.png to 0_0.23_phase00167a.png
# Renaming phase00167b.png to 0_0.23_phase00167b.png
# Renaming phase00168a.png to 1_0.63_phase00168a.png
# Renaming phase00168b.png to 1_0.63_phase00168b.png
# Renaming phase00170a.png to 1_0.65_phase00170a.png
# Renaming phase00170b.png to 1_0.65_phase00170b.png
# Renaming phase00171a.png to 1_0.41_phase00171a.png
# Renaming phase00171b.png to 1_0.41_phase00171b.png
# Renaming phase00172a.png to 1_0.70_phase00172a.png
# Renaming phase00172b.png to 1_0.70_phase00172b.png
# Renaming phase00173a.png to 1_0.55_phase00173a.png
# Renaming phase00173b.png to 1_0.55_phase00173b.png
# Renaming phase00174a.png to 1_0.34_phase00174a.png
# Renaming phase00174b.png to 1_0.34_phase00174b.png
# Renaming phase00175a.png to 1_0.45_phase00175a.png
# Renaming phase00175b.png to 1_0.45_phase00175b.png
# Renaming phase00177a.png to 1_0.53_phase00177a.png
# Renaming phase00177b.png to 1_0.53_phase00177b.png
# Renaming phase00178a.png to 0_0.72_phase00178a.png
# Renaming phase00178b.png to 0_0.72_phase00178b.png
# Renaming phase00179a.png to 0_0.18_phase00179a.png
# Renaming phase00179b.png to 0_0.18_phase00179b.png
# Renaming phase00180a.png to 0_0.22_phase00180a.png
# Renaming phase00180b.png to 0_0.22_phase00180b.png
# Renaming phase00181a.png to 1_0.65_phase00181a.png
# Renaming phase00181b.png to 1_0.65_phase00181b.png
# Renaming phase00182a.png to 1_0.52_phase00182a.png
# Renaming phase00182b.png to 1_0.52_phase00182b.png
# Renaming phase00183a.png to 0_0.26_phase00183a.png
# Renaming phase00183b.png to 0_0.26_phase00183b.png
# Renaming phase00184a.png to 0_0.19_phase00184a.png
# Renaming phase00184b.png to 0_0.19_phase00184b.png
# Renaming phase00185a.png to 1_0.72_phase00185a.png
# Renaming phase00185b.png to 1_0.72_phase00185b.png
# Renaming phase00186a.png to 1_0.36_phase00186a.png
# Renaming phase00186b.png to 1_0.36_phase00186b.png
# Renaming phase00187a.png to 0_0.32_phase00187a.png
# Renaming phase00187b.png to 0_0.32_phase00187b.png
# Renaming phase00188a.png to 1_0.39_phase00188a.png
# Renaming phase00188b.png to 1_0.39_phase00188b.png
# Renaming phase00189a.png to 0_0.62_phase00189a.png
# Renaming phase00189b.png to 0_0.62_phase00189b.png
# Renaming phase00190a.png to 1_0.67_phase00190a.png
# Renaming phase00190b.png to 1_0.67_phase00190b.png
# Renaming phase00191a.png to 1_0.32_phase00191a.png
# Renaming phase00191b.png to 1_0.32_phase00191b.png
# Renaming phase00193a.png to 1_0.72_phase00193a.png
# Renaming phase00193b.png to 1_0.72_phase00193b.png
# Renaming phase00194a.png to 1_0.58_phase00194a.png
# Renaming phase00194b.png to 1_0.58_phase00194b.png
# Renaming phase00195a.png to 1_0.20_phase00195a.png
# Renaming phase00195b.png to 1_0.20_phase00195b.png
# Renaming phase00196a.png to 1_0.75_phase00196a.png
# Renaming phase00196b.png to 1_0.75_phase00196b.png
# Renaming phase00197a.png to 1_0.29_phase00197a.png
# Renaming phase00197b.png to 1_0.29_phase00197b.png
# Renaming phase00198a.png to 1_0.22_phase00198a.png
# Renaming phase00198b.png to 1_0.22_phase00198b.png
# Renaming phase00199a.png to 1_0.65_phase00199a.png
# Renaming phase00199b.png to 1_0.65_phase00199b.png
# Renaming phase00200a.png to 1_0.71_phase00200a.png
# Renaming phase00200b.png to 1_0.71_phase00200b.png
# Renaming phase00201a.png to 0_0.22_phase00201a.png
# Renaming phase00201b.png to 0_0.22_phase00201b.png
# Renaming phase00202a.png to 1_0.52_phase00202a.png
# Renaming phase00202b.png to 1_0.52_phase00202b.png
# Renaming phase00203a.png to 1_0.41_phase00203a.png
# Renaming phase00203b.png to 1_0.41_phase00203b.png
# Renaming phase00204a.png to 1_0.52_phase00204a.png
# Renaming phase00204b.png to 1_0.52_phase00204b.png
# Renaming phase00205a.png to 0_0.28_phase00205a.png
# Renaming phase00205b.png to 0_0.28_phase00205b.png
# Renaming phase00206a.png to 1_0.41_phase00206a.png
# Renaming phase00206b.png to 1_0.41_phase00206b.png
# Renaming phase00207a.png to 1_0.44_phase00207a.png
# Renaming phase00207b.png to 1_0.44_phase00207b.png
# Renaming phase00208a.png to 1_0.35_phase00208a.png
# Renaming phase00208b.png to 1_0.35_phase00208b.png
# Renaming phase00209a.png to 1_0.34_phase00209a.png
# Renaming phase00209b.png to 1_0.34_phase00209b.png
# Renaming phase00210a.png to 1_0.32_phase00210a.png
# Renaming phase00210b.png to 1_0.32_phase00210b.png
# Renaming phase00211a.png to 1_0.46_phase00211a.png
# Renaming phase00211b.png to 1_0.46_phase00211b.png
# Renaming phase00212a.png to 1_0.60_phase00212a.png
# Renaming phase00212b.png to 1_0.60_phase00212b.png
# Renaming phase00213a.png to 1_0.41_phase00213a.png
# Renaming phase00213b.png to 1_0.41_phase00213b.png
# Renaming phase00214a.png to 0_0.25_phase00214a.png
# Renaming phase00214b.png to 0_0.25_phase00214b.png
# Renaming phase00216a.png to 1_0.66_phase00216a.png
# Renaming phase00216b.png to 1_0.66_phase00216b.png
# Renaming phase00217a.png to 1_0.32_phase00217a.png
# Renaming phase00217b.png to 1_0.32_phase00217b.png
# Renaming phase00218a.png to 0_0.28_phase00218a.png
# Renaming phase00218b.png to 0_0.28_phase00218b.png
# Renaming phase00219a.png to 0_0.20_phase00219a.png
# Renaming phase00219b.png to 0_0.20_phase00219b.png
# Renaming phase00220a.png to 1_0.33_phase00220a.png
# Renaming phase00220b.png to 1_0.33_phase00220b.png
# Renaming phase00221a.png to 0_0.59_phase00221a.png
# Renaming phase00221b.png to 0_0.59_phase00221b.png
# Renaming phase00223a.png to 1_0.33_phase00223a.png
# Renaming phase00223b.png to 1_0.33_phase00223b.png
# Renaming phase00224a.png to 1_0.53_phase00224a.png
# Renaming phase00224b.png to 1_0.53_phase00224b.png
# Renaming phase00225a.png to 0_0.49_phase00225a.png
# Renaming phase00225b.png to 0_0.49_phase00225b.png
# Renaming phase00226a.png to 0_0.30_phase00226a.png
# Renaming phase00226b.png to 0_0.30_phase00226b.png
# Renaming phase00227a.png to 0_0.35_phase00227a.png
# Renaming phase00227b.png to 0_0.35_phase00227b.png
# Renaming phase00228a.png to 1_0.40_phase00228a.png
# Renaming phase00228b.png to 1_0.40_phase00228b.png
# Renaming phase00229a.png to 0_0.48_phase00229a.png
# Renaming phase00229b.png to 0_0.48_phase00229b.png
# Renaming phase00230a.png to 1_0.59_phase00230a.png
# Renaming phase00230b.png to 1_0.59_phase00230b.png
# Renaming phase00231a.png to 1_0.43_phase00231a.png
# Renaming phase00231b.png to 1_0.43_phase00231b.png
# Renaming phase00232a.png to 0_0.45_phase00232a.png
# Renaming phase00232b.png to 0_0.45_phase00232b.png
# Renaming phase00233a.png to 0_0.35_phase00233a.png
# Renaming phase00233b.png to 0_0.35_phase00233b.png
# Renaming phase00236a.png to 0_0.21_phase00236a.png
# Renaming phase00236b.png to 0_0.21_phase00236b.png
# Renaming phase00237a.png to 1_0.39_phase00237a.png
# Renaming phase00237b.png to 1_0.39_phase00237b.png
# Renaming phase00239a.png to 1_0.34_phase00239a.png
# Renaming phase00239b.png to 1_0.34_phase00239b.png
# Renaming phase00240a.png to 1_0.57_phase00240a.png
# Renaming phase00240b.png to 1_0.57_phase00240b.png
# Renaming phase00241a.png to 1_0.49_phase00241a.png
# Renaming phase00241b.png to 1_0.49_phase00241b.png
# Renaming phase00242a.png to 1_0.37_phase00242a.png
# Renaming phase00242b.png to 1_0.37_phase00242b.png
# Renaming phase00243a.png to 1_0.51_phase00243a.png
# Renaming phase00243b.png to 1_0.51_phase00243b.png
# Renaming phase00244a.png to 0_0.26_phase00244a.png
# Renaming phase00244b.png to 0_0.26_phase00244b.png
# Renaming phase00245a.png to 0_0.18_phase00245a.png
# Renaming phase00245b.png to 0_0.18_phase00245b.png
# Renaming phase00246a.png to 1_0.68_phase00246a.png
# Renaming phase00246b.png to 1_0.68_phase00246b.png
# Renaming phase00247a.png to 1_0.31_phase00247a.png
# Renaming phase00247b.png to 1_0.31_phase00247b.png
# Renaming phase00249a.png to 1_0.62_phase00249a.png
# Renaming phase00249b.png to 1_0.62_phase00249b.png
# Renaming phase00250a.png to 0_0.26_phase00250a.png
# Renaming phase00250b.png to 0_0.26_phase00250b.png
# Renaming phase00251a.png to 0_0.30_phase00251a.png
# Renaming phase00251b.png to 0_0.30_phase00251b.png
# Renaming phase00252a.png to 1_0.60_phase00252a.png
# Renaming phase00252b.png to 1_0.60_phase00252b.png
# Renaming phase00254a.png to 1_0.52_phase00254a.png
# Renaming phase00254b.png to 1_0.52_phase00254b.png
# Renaming phase00255a.png to 1_0.65_phase00255a.png
# Renaming phase00255b.png to 1_0.65_phase00255b.png
# Renaming phase00256a.png to 1_0.68_phase00256a.png
# Renaming phase00256b.png to 1_0.68_phase00256b.png
# Renaming phase00258a.png to 0_0.64_phase00258a.png
# Renaming phase00258b.png to 0_0.64_phase00258b.png
# Renaming phase00259a.png to 1_0.31_phase00259a.png
# Renaming phase00259b.png to 1_0.31_phase00259b.png
# Renaming phase00260a.png to 1_0.84_phase00260a.png
# Renaming phase00260b.png to 1_0.84_phase00260b.png
# Renaming phase00261a.png to 1_0.38_phase00261a.png
# Renaming phase00261b.png to 1_0.38_phase00261b.png
# Renaming phase00262a.png to 1_0.48_phase00262a.png
# Renaming phase00262b.png to 1_0.48_phase00262b.png
# Renaming phase00263a.png to 1_0.46_phase00263a.png
# Renaming phase00263b.png to 1_0.46_phase00263b.png
# Renaming phase00264a.png to 1_0.72_phase00264a.png
# Renaming phase00264b.png to 1_0.72_phase00264b.png
# Renaming phase00265a.png to 1_0.61_phase00265a.png
# Renaming phase00265b.png to 1_0.61_phase00265b.png
# Renaming phase00266a.png to 0_0.67_phase00266a.png
# Renaming phase00266b.png to 0_0.67_phase00266b.png
# Renaming phase00268a.png to 0_0.30_phase00268a.png
# Renaming phase00268b.png to 0_0.30_phase00268b.png
# Renaming phase00269a.png to 1_0.60_phase00269a.png
# Renaming phase00269b.png to 1_0.60_phase00269b.png
# Renaming phase00270a.png to 1_0.51_phase00270a.png
# Renaming phase00270b.png to 1_0.51_phase00270b.png
# Renaming phase00271a.png to 1_0.58_phase00271a.png
# Renaming phase00271b.png to 1_0.58_phase00271b.png
# Renaming phase00272a.png to 1_0.35_phase00272a.png
# Renaming phase00272b.png to 1_0.35_phase00272b.png
# Renaming phase00274a.png to 1_0.63_phase00274a.png
# Renaming phase00274b.png to 1_0.63_phase00274b.png
# Renaming phase00275a.png to 1_0.43_phase00275a.png
# Renaming phase00275b.png to 1_0.43_phase00275b.png
# Renaming phase00276a.png to 0_0.23_phase00276a.png
# Renaming phase00276b.png to 0_0.23_phase00276b.png
# Renaming phase00277a.png to 0_0.69_phase00277a.png
# Renaming phase00277b.png to 0_0.69_phase00277b.png
# Renaming phase00278a.png to 0_0.51_phase00278a.png
# Renaming phase00278b.png to 0_0.51_phase00278b.png
# Renaming phase00279a.png to 1_0.72_phase00279a.png
# Renaming phase00279b.png to 1_0.72_phase00279b.png
# Renaming phase00280a.png to 0_0.27_phase00280a.png
# Renaming phase00280b.png to 0_0.27_phase00280b.png
# Renaming phase00281a.png to 1_0.59_phase00281a.png
# Renaming phase00281b.png to 1_0.59_phase00281b.png
# Renaming phase00282a.png to 1_0.63_phase00282a.png
# Renaming phase00282b.png to 1_0.63_phase00282b.png
# Renaming phase00283a.png to 0_0.24_phase00283a.png
# Renaming phase00283b.png to 0_0.24_phase00283b.png
# Renaming phase00285a.png to 0_0.33_phase00285a.png
# Renaming phase00285b.png to 0_0.33_phase00285b.png
# Renaming phase00286a.png to 1_0.34_phase00286a.png
# Renaming phase00286b.png to 1_0.34_phase00286b.png
# Renaming phase00287a.png to 0_0.93_phase00287a.png
# Renaming phase00287b.png to 0_0.93_phase00287b.png
# Renaming phase00288a.png to 0_0.32_phase00288a.png
# Renaming phase00288b.png to 0_0.32_phase00288b.png
# Renaming phase00290a.png to 0_0.60_phase00290a.png
# Renaming phase00290b.png to 0_0.60_phase00290b.png
# Renaming phase00291a.png to 1_0.71_phase00291a.png
# Renaming phase00291b.png to 1_0.71_phase00291b.png
# Renaming phase00292a.png to 1_0.49_phase00292a.png
# Renaming phase00292b.png to 1_0.49_phase00292b.png
# Renaming phase00293a.png to 1_0.59_phase00293a.png
# Renaming phase00293b.png to 1_0.59_phase00293b.png
# Renaming phase00294a.png to 1_0.85_phase00294a.png
# Renaming phase00294b.png to 1_0.85_phase00294b.png
# Renaming phase00295a.png to 1_0.71_phase00295a.png
# Renaming phase00295b.png to 1_0.71_phase00295b.png
# Renaming phase00296a.png to 0_0.29_phase00296a.png
# Renaming phase00296b.png to 0_0.29_phase00296b.png
# Renaming phase00297a.png to 1_0.65_phase00297a.png
# Renaming phase00297b.png to 1_0.65_phase00297b.png
# Renaming phase00298a.png to 1_0.51_phase00298a.png
# Renaming phase00298b.png to 1_0.51_phase00298b.png
# Renaming phase00299a.png to 1_0.39_phase00299a.png
# Renaming phase00299b.png to 1_0.39_phase00299b.png
# Renaming phase00301a.png to 1_0.59_phase00301a.png
# Renaming phase00301b.png to 1_0.59_phase00301b.png
# Renaming phase00302a.png to 0_0.41_phase00302a.png
# Renaming phase00302b.png to 0_0.41_phase00302b.png
# Renaming phase00303a.png to 1_0.55_phase00303a.png
# Renaming phase00303b.png to 1_0.55_phase00303b.png
# Renaming phase00304a.png to 1_0.45_phase00304a.png
# Renaming phase00304b.png to 1_0.45_phase00304b.png
# Renaming phase00305a.png to 0_0.33_phase00305a.png
# Renaming phase00305b.png to 0_0.33_phase00305b.png
# Renaming phase00306a.png to 1_0.29_phase00306a.png
# Renaming phase00306b.png to 1_0.29_phase00306b.png
# Renaming phase00307a.png to 0_0.25_phase00307a.png
# Renaming phase00307b.png to 0_0.25_phase00307b.png
# Renaming phase00308a.png to 1_0.58_phase00308a.png
# Renaming phase00308b.png to 1_0.58_phase00308b.png
# Renaming phase00309a.png to 0_0.35_phase00309a.png
# Renaming phase00309b.png to 0_0.35_phase00309b.png
# Renaming phase00310a.png to 1_0.41_phase00310a.png
# Renaming phase00310b.png to 1_0.41_phase00310b.png
# Renaming phase00312a.png to 1_0.41_phase00312a.png
# Renaming phase00312b.png to 1_0.41_phase00312b.png
# Renaming phase00313a.png to 1_0.52_phase00313a.png
# Renaming phase00313b.png to 1_0.52_phase00313b.png
# Renaming phase00314a.png to 0_0.26_phase00314a.png
# Renaming phase00314b.png to 0_0.26_phase00314b.png
# Renaming phase00315a.png to 0_0.21_phase00315a.png
# Renaming phase00315b.png to 0_0.21_phase00315b.png
# Renaming phase00316a.png to 1_0.58_phase00316a.png
# Renaming phase00316b.png to 1_0.58_phase00316b.png
# Renaming phase00317a.png to 0_0.39_phase00317a.png
# Renaming phase00317b.png to 0_0.39_phase00317b.png
# Renaming phase00318a.png to 0_0.36_phase00318a.png
# Renaming phase00318b.png to 0_0.36_phase00318b.png
# Renaming phase00319a.png to 1_0.39_phase00319a.png
# Renaming phase00319b.png to 1_0.39_phase00319b.png
# Renaming phase00320a.png to 1_0.63_phase00320a.png
# Renaming phase00320b.png to 1_0.63_phase00320b.png
# Renaming phase00321a.png to 0_0.53_phase00321a.png
# Renaming phase00321b.png to 0_0.53_phase00321b.png
# Renaming phase00322a.png to 1_0.79_phase00322a.png
# Renaming phase00322b.png to 1_0.79_phase00322b.png
# Renaming phase00323a.png to 1_0.50_phase00323a.png
# Renaming phase00323b.png to 1_0.50_phase00323b.png
# Renaming phase00324a.png to 1_0.35_phase00324a.png
# Renaming phase00324b.png to 1_0.35_phase00324b.png
# Renaming phase00325a.png to 1_0.67_phase00325a.png
# Renaming phase00325b.png to 1_0.67_phase00325b.png
# Renaming phase00326a.png to 0_0.32_phase00326a.png
# Renaming phase00326b.png to 0_0.32_phase00326b.png
# Renaming phase00328a.png to 1_0.46_phase00328a.png
# Renaming phase00328b.png to 1_0.46_phase00328b.png
# Renaming phase00329a.png to 1_0.79_phase00329a.png
# Renaming phase00329b.png to 1_0.79_phase00329b.png
# Renaming phase00330a.png to 1_0.71_phase00330a.png
# Renaming phase00330b.png to 1_0.71_phase00330b.png
# Renaming phase00331a.png to 1_0.48_phase00331a.png
# Renaming phase00331b.png to 1_0.48_phase00331b.png
# Renaming phase00332a.png to 0_0.37_phase00332a.png
# Renaming phase00332b.png to 0_0.37_phase00332b.png
# Renaming phase00334a.png to 1_0.58_phase00334a.png
# Renaming phase00334b.png to 1_0.58_phase00334b.png
# Renaming phase00335a.png to 0_0.20_phase00335a.png
# Renaming phase00335b.png to 0_0.20_phase00335b.png
# Renaming phase00336a.png to 1_0.84_phase00336a.png
# Renaming phase00336b.png to 1_0.84_phase00336b.png
# Renaming phase00337a.png to 1_0.38_phase00337a.png
# Renaming phase00337b.png to 1_0.38_phase00337b.png
# Renaming phase00338a.png to 0_0.41_phase00338a.png
# Renaming phase00338b.png to 0_0.41_phase00338b.png
# Renaming phase00340a.png to 1_0.53_phase00340a.png
# Renaming phase00340b.png to 1_0.53_phase00340b.png
# Renaming phase00342a.png to 1_0.36_phase00342a.png
# Renaming phase00342b.png to 1_0.36_phase00342b.png
# Renaming phase00343a.png to 1_0.41_phase00343a.png
# Renaming phase00343b.png to 1_0.41_phase00343b.png
# Renaming phase00344a.png to 0_0.22_phase00344a.png
# Renaming phase00344b.png to 0_0.22_phase00344b.png
# Renaming phase00345a.png to 0_0.31_phase00345a.png
# Renaming phase00345b.png to 0_0.31_phase00345b.png
# Renaming phase00347a.png to 1_0.50_phase00347a.png
# Renaming phase00347b.png to 1_0.50_phase00347b.png
# Renaming phase00348a.png to 0_0.74_phase00348a.png
# Renaming phase00348b.png to 0_0.74_phase00348b.png
# Renaming phase00349a.png to 0_0.40_phase00349a.png
# Renaming phase00349b.png to 0_0.40_phase00349b.png
# Renaming phase00350a.png to 1_0.63_phase00350a.png
# Renaming phase00350b.png to 1_0.63_phase00350b.png
# Renaming phase00352a.png to 1_0.24_phase00352a.png
# Renaming phase00352b.png to 1_0.24_phase00352b.png
# Renaming phase00353a.png to 1_0.56_phase00353a.png
# Renaming phase00353b.png to 1_0.56_phase00353b.png
# Renaming phase00354a.png to 1_0.23_phase00354a.png
# Renaming phase00354b.png to 1_0.23_phase00354b.png
# Renaming phase00355a.png to 1_0.75_phase00355a.png
# Renaming phase00355b.png to 1_0.75_phase00355b.png
# Renaming phase00356a.png to 0_0.33_phase00356a.png
# Renaming phase00356b.png to 0_0.33_phase00356b.png
# Renaming phase00357a.png to 1_0.67_phase00357a.png
# Renaming phase00357b.png to 1_0.67_phase00357b.png
# Renaming phase00358a.png to 1_0.35_phase00358a.png
# Renaming phase00358b.png to 1_0.35_phase00358b.png
# Renaming phase00359a.png to 1_0.51_phase00359a.png
# Renaming phase00359b.png to 1_0.51_phase00359b.png
# Renaming phase00360a.png to 1_0.40_phase00360a.png
# Renaming phase00360b.png to 1_0.40_phase00360b.png
# Renaming phase00361a.png to 1_0.78_phase00361a.png
# Renaming phase00361b.png to 1_0.78_phase00361b.png
# Renaming phase00362a.png to 0_0.21_phase00362a.png
# Renaming phase00362b.png to 0_0.21_phase00362b.png
# Renaming phase00363a.png to 0_0.36_phase00363a.png
# Renaming phase00363b.png to 0_0.36_phase00363b.png
# Renaming phase00364a.png to 1_0.48_phase00364a.png
# Renaming phase00364b.png to 1_0.48_phase00364b.png
# Renaming phase00365a.png to 0_0.48_phase00365a.png
# Renaming phase00365b.png to 0_0.48_phase00365b.png
# Renaming phase00366a.png to 1_0.40_phase00366a.png
# Renaming phase00366b.png to 1_0.40_phase00366b.png
# Renaming phase00368a.png to 0_0.23_phase00368a.png
# Renaming phase00368b.png to 0_0.23_phase00368b.png
# Renaming phase00370a.png to 1_0.39_phase00370a.png
# Renaming phase00370b.png to 1_0.39_phase00370b.png
# Renaming phase00371a.png to 1_0.69_phase00371a.png
# Renaming phase00371b.png to 1_0.69_phase00371b.png
# Renaming phase00372a.png to 1_0.73_phase00372a.png
# Renaming phase00372b.png to 1_0.73_phase00372b.png
# Renaming phase00373a.png to 0_0.40_phase00373a.png
# Renaming phase00373b.png to 0_0.40_phase00373b.png
# Renaming phase00374a.png to 0_0.22_phase00374a.png
# Renaming phase00374b.png to 0_0.22_phase00374b.png
# Renaming phase00375a.png to 0_0.19_phase00375a.png
# Renaming phase00375b.png to 0_0.19_phase00375b.png
# Renaming phase00376a.png to 0_0.21_phase00376a.png
# Renaming phase00376b.png to 0_0.21_phase00376b.png
# Renaming phase00377a.png to 0_0.26_phase00377a.png
# Renaming phase00377b.png to 0_0.26_phase00377b.png
# Renaming phase00378a.png to 0_0.22_phase00378a.png
# Renaming phase00378b.png to 0_0.22_phase00378b.png
# Renaming phase00379a.png to 0_0.26_phase00379a.png
# Renaming phase00379b.png to 0_0.26_phase00379b.png
# Renaming phase00380a.png to 0_0.21_phase00380a.png
# Renaming phase00380b.png to 0_0.21_phase00380b.png
# Renaming phase00383a.png to 1_0.34_phase00383a.png
# Renaming phase00383b.png to 1_0.34_phase00383b.png
# Renaming phase00384a.png to 0_0.26_phase00384a.png
# Renaming phase00384b.png to 0_0.26_phase00384b.png
# Renaming phase00385a.png to 0_0.26_phase00385a.png
# Renaming phase00385b.png to 0_0.26_phase00385b.png
# Renaming phase00386a.png to 0_0.21_phase00386a.png
# Renaming phase00386b.png to 0_0.21_phase00386b.png
# Renaming phase00387a.png to 0_0.20_phase00387a.png
# Renaming phase00387b.png to 0_0.20_phase00387b.png
# Renaming phase00388a.png to 1_0.58_phase00388a.png
# Renaming phase00388b.png to 1_0.58_phase00388b.png
# Renaming phase00389a.png to 1_0.43_phase00389a.png
# Renaming phase00389b.png to 1_0.43_phase00389b.png
# Renaming phase00391a.png to 1_0.56_phase00391a.png
# Renaming phase00391b.png to 1_0.56_phase00391b.png
# Renaming phase00392a.png to 1_0.89_phase00392a.png
# Renaming phase00392b.png to 1_0.89_phase00392b.png
# Renaming phase00393a.png to 0_0.26_phase00393a.png
# Renaming phase00393b.png to 0_0.26_phase00393b.png
# Renaming phase00394a.png to 1_0.70_phase00394a.png
# Renaming phase00394b.png to 1_0.70_phase00394b.png
# Renaming phase00395a.png to 1_0.78_phase00395a.png
# Renaming phase00395b.png to 1_0.78_phase00395b.png
# Renaming phase00398a.png to 0_0.29_phase00398a.png
# Renaming phase00398b.png to 0_0.29_phase00398b.png
# Renaming phase00399a.png to 1_0.40_phase00399a.png
# Renaming phase00399b.png to 1_0.40_phase00399b.png
# Renaming phase00400a.png to 0_0.25_phase00400a.png
# Renaming phase00400b.png to 0_0.25_phase00400b.png
# Renaming phase00402a.png to 1_0.30_phase00402a.png
# Renaming phase00402b.png to 1_0.30_phase00402b.png
# Renaming phase00403a.png to 1_0.48_phase00403a.png
# Renaming phase00403b.png to 1_0.48_phase00403b.png
# Renaming phase00405a.png to 1_0.61_phase00405a.png
# Renaming phase00405b.png to 1_0.61_phase00405b.png
# Renaming phase00406a.png to 1_0.80_phase00406a.png
# Renaming phase00406b.png to 1_0.80_phase00406b.png
# Renaming phase00408a.png to 0_0.32_phase00408a.png
# Renaming phase00408b.png to 0_0.32_phase00408b.png
# Renaming phase00409a.png to 1_0.42_phase00409a.png
# Renaming phase00409b.png to 1_0.42_phase00409b.png
# Renaming phase00410a.png to 0_0.44_phase00410a.png
# Renaming phase00410b.png to 0_0.44_phase00410b.png
# Renaming phase00411a.png to 0_0.20_phase00411a.png
# Renaming phase00411b.png to 0_0.20_phase00411b.png
# Renaming phase00412a.png to 0_0.25_phase00412a.png
# Renaming phase00412b.png to 0_0.25_phase00412b.png
# Renaming phase00413a.png to 1_0.69_phase00413a.png
# Renaming phase00413b.png to 1_0.69_phase00413b.png
# Renaming phase00414a.png to 0_0.62_phase00414a.png
# Renaming phase00414b.png to 0_0.62_phase00414b.png
# Renaming phase00416a.png to 0_0.23_phase00416a.png
# Renaming phase00416b.png to 0_0.23_phase00416b.png
# Renaming phase00417a.png to 1_0.73_phase00417a.png
# Renaming phase00417b.png to 1_0.73_phase00417b.png
# Renaming phase00418a.png to 1_0.59_phase00418a.png
# Renaming phase00418b.png to 1_0.59_phase00418b.png
# Renaming phase00419a.png to 0_0.30_phase00419a.png
# Renaming phase00419b.png to 0_0.30_phase00419b.png
# Renaming phase00420a.png to 0_0.25_phase00420a.png
# Renaming phase00420b.png to 0_0.25_phase00420b.png
# Renaming phase00421a.png to 0_0.21_phase00421a.png
# Renaming phase00421b.png to 0_0.21_phase00421b.png
# Renaming phase00426a.png to 1_0.52_phase00426a.png
# Renaming phase00426b.png to 1_0.52_phase00426b.png
# Renaming phase00427a.png to 0_0.23_phase00427a.png
# Renaming phase00427b.png to 0_0.23_phase00427b.png
# Renaming phase00428a.png to 0_0.24_phase00428a.png
# Renaming phase00428b.png to 0_0.24_phase00428b.png
# Renaming phase00429a.png to 1_0.59_phase00429a.png
# Renaming phase00429b.png to 1_0.59_phase00429b.png
# Renaming phase00430a.png to 0_0.40_phase00430a.png
# Renaming phase00430b.png to 0_0.40_phase00430b.png
# Renaming phase00431a.png to 0_0.45_phase00431a.png
# Renaming phase00431b.png to 0_0.45_phase00431b.png
# Renaming phase00432a.png to 1_0.41_phase00432a.png
# Renaming phase00432b.png to 1_0.41_phase00432b.png
# Renaming phase00433a.png to 0_0.23_phase00433a.png
# Renaming phase00433b.png to 0_0.23_phase00433b.png
# Renaming phase00434a.png to 1_0.65_phase00434a.png
# Renaming phase00434b.png to 1_0.65_phase00434b.png
# Renaming phase00435a.png to 1_0.71_phase00435a.png
# Renaming phase00435b.png to 1_0.71_phase00435b.png
# Renaming phase00436a.png to 1_0.38_phase00436a.png
# Renaming phase00436b.png to 1_0.38_phase00436b.png
# Renaming phase00437a.png to 1_0.30_phase00437a.png
# Renaming phase00437b.png to 1_0.30_phase00437b.png
# Renaming phase00439a.png to 1_0.34_phase00439a.png
# Renaming phase00439b.png to 1_0.34_phase00439b.png
# Renaming phase00440a.png to 1_0.91_phase00440a.png
# Renaming phase00440b.png to 1_0.91_phase00440b.png
# Renaming phase00441a.png to 1_0.39_phase00441a.png
# Renaming phase00441b.png to 1_0.39_phase00441b.png
# Renaming phase00442a.png to 1_0.79_phase00442a.png
# Renaming phase00442b.png to 1_0.79_phase00442b.png
# Renaming phase00443a.png to 0_0.24_phase00443a.png
# Renaming phase00443b.png to 0_0.24_phase00443b.png
# Renaming phase00444a.png to 0_0.28_phase00444a.png
# Renaming phase00444b.png to 0_0.28_phase00444b.png
# Renaming phase00445a.png to 0_0.26_phase00445a.png
# Renaming phase00445b.png to 0_0.26_phase00445b.png
# Renaming phase00446a.png to 1_0.42_phase00446a.png
# Renaming phase00446b.png to 1_0.42_phase00446b.png
# Renaming phase00447a.png to 1_0.38_phase00447a.png
# Renaming phase00447b.png to 1_0.38_phase00447b.png
# Renaming phase00448a.png to 1_0.72_phase00448a.png
# Renaming phase00448b.png to 1_0.72_phase00448b.png
# Renaming phase00449a.png to 0_0.23_phase00449a.png
# Renaming phase00449b.png to 0_0.23_phase00449b.png
# Renaming phase00451a.png to 0_0.28_phase00451a.png
# Renaming phase00451b.png to 0_0.28_phase00451b.png
# Renaming phase00452a.png to 1_0.53_phase00452a.png
# Renaming phase00452b.png to 1_0.53_phase00452b.png
# Renaming phase00453a.png to 1_0.51_phase00453a.png
# Renaming phase00453b.png to 1_0.51_phase00453b.png
# Renaming phase00454a.png to 0_0.90_phase00454a.png
# Renaming phase00454b.png to 0_0.90_phase00454b.png
# Renaming phase00455a.png to 0_0.23_phase00455a.png
# Renaming phase00455b.png to 0_0.23_phase00455b.png
# Renaming phase00456a.png to 1_0.25_phase00456a.png
# Renaming phase00456b.png to 1_0.25_phase00456b.png
# Renaming phase00457a.png to 0_0.24_phase00457a.png
# Renaming phase00457b.png to 0_0.24_phase00457b.png
# Renaming phase00458a.png to 0_0.30_phase00458a.png
# Renaming phase00458b.png to 0_0.30_phase00458b.png
# Renaming phase00459a.png to 1_0.50_phase00459a.png
# Renaming phase00459b.png to 1_0.50_phase00459b.png
# Renaming phase00460a.png to 1_0.69_phase00460a.png
# Renaming phase00460b.png to 1_0.69_phase00460b.png
# Renaming phase00461a.png to 0_0.26_phase00461a.png
# Renaming phase00461b.png to 0_0.26_phase00461b.png
# Renaming phase00463a.png to 0_0.26_phase00463a.png
# Renaming phase00463b.png to 0_0.26_phase00463b.png
# Renaming phase00464a.png to 0_0.30_phase00464a.png
# Renaming phase00464b.png to 0_0.30_phase00464b.png
# Renaming phase00468a.png to 0_0.27_phase00468a.png
# Renaming phase00468b.png to 0_0.27_phase00468b.png
# Renaming phase00470a.png to 0_0.27_phase00470a.png
# Renaming phase00470b.png to 0_0.27_phase00470b.png
# Renaming phase00471a.png to 0_0.25_phase00471a.png
# Renaming phase00471b.png to 0_0.25_phase00471b.png
# Renaming phase00473a.png to 1_0.76_phase00473a.png
# Renaming phase00473b.png to 1_0.76_phase00473b.png
# Renaming phase00474a.png to 1_0.48_phase00474a.png
# Renaming phase00474b.png to 1_0.48_phase00474b.png
# Renaming phase00475a.png to 1_0.45_phase00475a.png
# Renaming phase00475b.png to 1_0.45_phase00475b.png
# Renaming phase00476a.png to 1_0.73_phase00476a.png
# Renaming phase00476b.png to 1_0.73_phase00476b.png
# Renaming phase00477a.png to 1_0.44_phase00477a.png
# Renaming phase00477b.png to 1_0.44_phase00477b.png
# Renaming phase00478a.png to 0_0.18_phase00478a.png
# Renaming phase00478b.png to 0_0.18_phase00478b.png
# Renaming phase00479a.png to 0_0.30_phase00479a.png
# Renaming phase00479b.png to 0_0.30_phase00479b.png
# Renaming phase00480a.png to 1_0.62_phase00480a.png
# Renaming phase00480b.png to 1_0.62_phase00480b.png
# Renaming phase00481a.png to 1_0.49_phase00481a.png
# Renaming phase00481b.png to 1_0.49_phase00481b.png
# Renaming phase00482a.png to 1_0.30_phase00482a.png
# Renaming phase00482b.png to 1_0.30_phase00482b.png
# Renaming phase00483a.png to 1_0.46_phase00483a.png
# Renaming phase00483b.png to 1_0.46_phase00483b.png
# Renaming phase00484a.png to 0_0.30_phase00484a.png
# Renaming phase00484b.png to 0_0.30_phase00484b.png
# Renaming phase00485a.png to 1_0.25_phase00485a.png
# Renaming phase00485b.png to 1_0.25_phase00485b.png
# Renaming phase00486a.png to 1_0.47_phase00486a.png
# Renaming phase00486b.png to 1_0.47_phase00486b.png
# Renaming phase00488a.png to 1_0.29_phase00488a.png
# Renaming phase00488b.png to 1_0.29_phase00488b.png
# Renaming phase00489a.png to 1_0.51_phase00489a.png
# Renaming phase00489b.png to 1_0.51_phase00489b.png
# Renaming phase00490a.png to 0_0.25_phase00490a.png
# Renaming phase00490b.png to 0_0.25_phase00490b.png
# Renaming phase00491a.png to 1_0.37_phase00491a.png
# Renaming phase00491b.png to 1_0.37_phase00491b.png
# Renaming phase00493a.png to 1_0.30_phase00493a.png
# Renaming phase00493b.png to 1_0.30_phase00493b.png
# Renaming phase00494a.png to 1_0.46_phase00494a.png
# Renaming phase00494b.png to 1_0.46_phase00494b.png
# Renaming phase00495a.png to 0_0.23_phase00495a.png
# Renaming phase00495b.png to 0_0.23_phase00495b.png
# Renaming phase00496a.png to 0_0.21_phase00496a.png
# Renaming phase00496b.png to 0_0.21_phase00496b.png
# Renaming phase00497a.png to 1_0.38_phase00497a.png
# Renaming phase00497b.png to 1_0.38_phase00497b.png
# Renaming phase00499a.png to 1_0.86_phase00499a.png
# Renaming phase00499b.png to 1_0.86_phase00499b.png
# Renaming phase00501a.png to 1_0.65_phase00501a.png
# Renaming phase00501b.png to 1_0.65_phase00501b.png
# Renaming phase00502a.png to 1_0.46_phase00502a.png
# Renaming phase00502b.png to 1_0.46_phase00502b.png
# Renaming phase00503a.png to 0_0.27_phase00503a.png
# Renaming phase00503b.png to 0_0.27_phase00503b.png
# Renaming phase00504a.png to 1_0.45_phase00504a.png
# Renaming phase00504b.png to 1_0.45_phase00504b.png
# Renaming phase00505a.png to 1_0.39_phase00505a.png
# Renaming phase00505b.png to 1_0.39_phase00505b.png
# Renaming phase00506a.png to 0_0.53_phase00506a.png
# Renaming phase00506b.png to 0_0.53_phase00506b.png
# Renaming phase00507a.png to 0_0.39_phase00507a.png
# Renaming phase00507b.png to 0_0.39_phase00507b.png
# Renaming phase00508a.png to 0_0.24_phase00508a.png
# Renaming phase00508b.png to 0_0.24_phase00508b.png
# Renaming phase00509a.png to 0_0.35_phase00509a.png
# Renaming phase00509b.png to 0_0.35_phase00509b.png
# Renaming phase00511a.png to 1_0.47_phase00511a.png
# Renaming phase00511b.png to 1_0.47_phase00511b.png
# Renaming phase00513a.png to 1_0.32_phase00513a.png
# Renaming phase00513b.png to 1_0.32_phase00513b.png
# Renaming phase00515a.png to 1_0.82_phase00515a.png
# Renaming phase00515b.png to 1_0.82_phase00515b.png
# Renaming phase00517a.png to 1_0.40_phase00517a.png
# Renaming phase00517b.png to 1_0.40_phase00517b.png
# Renaming phase00518a.png to 1_0.79_phase00518a.png
# Renaming phase00518b.png to 1_0.79_phase00518b.png
# Renaming phase00519a.png to 0_0.27_phase00519a.png
# Renaming phase00519b.png to 0_0.27_phase00519b.png
# Renaming phase00520a.png to 1_0.43_phase00520a.png
# Renaming phase00520b.png to 1_0.43_phase00520b.png
# Renaming phase00521a.png to 1_0.64_phase00521a.png
# Renaming phase00521b.png to 1_0.64_phase00521b.png
# Renaming phase00522a.png to 0_0.24_phase00522a.png
# Renaming phase00522b.png to 0_0.24_phase00522b.png
# Renaming phase00523a.png to 1_0.39_phase00523a.png
# Renaming phase00523b.png to 1_0.39_phase00523b.png
# Renaming phase00524a.png to 1_0.48_phase00524a.png
# Renaming phase00524b.png to 1_0.48_phase00524b.png
# Renaming phase00525a.png to 0_0.25_phase00525a.png
# Renaming phase00525b.png to 0_0.25_phase00525b.png
# Renaming phase00526a.png to 1_0.54_phase00526a.png
# Renaming phase00526b.png to 1_0.54_phase00526b.png
# Renaming phase00527a.png to 0_0.24_phase00527a.png
# Renaming phase00527b.png to 0_0.24_phase00527b.png
# Renaming phase00528a.png to 1_0.38_phase00528a.png
# Renaming phase00528b.png to 1_0.38_phase00528b.png
# Renaming phase00530a.png to 0_0.21_phase00530a.png
# Renaming phase00530b.png to 0_0.21_phase00530b.png
# Renaming phase00531a.png to 1_0.35_phase00531a.png
# Renaming phase00531b.png to 1_0.35_phase00531b.png
# Renaming phase00533a.png to 0_0.22_phase00533a.png
# Renaming phase00533b.png to 0_0.22_phase00533b.png
# Renaming phase00534a.png to 1_0.47_phase00534a.png
# Renaming phase00534b.png to 1_0.47_phase00534b.png
# Renaming phase00535a.png to 0_0.32_phase00535a.png
# Renaming phase00535b.png to 0_0.32_phase00535b.png
# Renaming phase00536a.png to 1_0.40_phase00536a.png
# Renaming phase00536b.png to 1_0.40_phase00536b.png
# Renaming phase00537a.png to 1_0.44_phase00537a.png
# Renaming phase00537b.png to 1_0.44_phase00537b.png
# Renaming phase00538a.png to 0_0.26_phase00538a.png
# Renaming phase00538b.png to 0_0.26_phase00538b.png
# Renaming phase00539a.png to 1_0.40_phase00539a.png
# Renaming phase00539b.png to 1_0.40_phase00539b.png
# Renaming phase00540a.png to 1_0.30_phase00540a.png
# Renaming phase00540b.png to 1_0.30_phase00540b.png
# Renaming phase00541a.png to 0_0.45_phase00541a.png
# Renaming phase00541b.png to 0_0.45_phase00541b.png
# Renaming phase00543a.png to 0_0.25_phase00543a.png
# Renaming phase00543b.png to 0_0.25_phase00543b.png
# Renaming phase00544a.png to 1_0.52_phase00544a.png
# ...
# Renaming phase09730b.png to 1_0.39_phase09730b.png
# Renaming phase09732a.png to 1_0.42_phase09732a.png
# Renaming phase09732b.png to 1_0.42_phase09732b.png
# Renaming phase09733a.png to 1_0.26_phase09733a.png
# Renaming phase09733b.png to 1_0.26_phase09733b.png
# Renaming phase09735a.png to 1_0.48_phase09735a.png
# Renaming phase09735b.png to 1_0.48_phase09735b.png
# Renaming phase09740a.png to 1_0.42_phase09740a.png
# Renaming phase09740b.png to 1_0.42_phase09740b.png
# Renaming phase09741a.png to 1_0.25_phase09741a.png
# Renaming phase09741b.png to 1_0.25_phase09741b.png
# Renaming phase09742a.png to 1_0.38_phase09742a.png
# Renaming phase09742b.png to 1_0.38_phase09742b.png
# Renaming phase09743a.png to 1_0.33_phase09743a.png
# Renaming phase09743b.png to 1_0.33_phase09743b.png
# Renaming phase09744a.png to 1_0.55_phase09744a.png
# Renaming phase09744b.png to 1_0.55_phase09744b.png
# Renaming phase09745a.png to 1_0.63_phase09745a.png
# Renaming phase09745b.png to 1_0.63_phase09745b.png
# Renaming phase09746a.png to 1_0.22_phase09746a.png
# Renaming phase09746b.png to 1_0.22_phase09746b.png
# Renaming phase09748a.png to 1_0.41_phase09748a.png
# Renaming phase09748b.png to 1_0.41_phase09748b.png
# Renaming phase09749a.png to 1_0.37_phase09749a.png
# Renaming phase09749b.png to 1_0.37_phase09749b.png
# Renaming phase09750a.png to 1_0.25_phase09750a.png
# Renaming phase09750b.png to 1_0.25_phase09750b.png
# Renaming phase09751a.png to 1_0.25_phase09751a.png
# Renaming phase09751b.png to 1_0.25_phase09751b.png
# Renaming phase09753a.png to 1_0.51_phase09753a.png
# Renaming phase09753b.png to 1_0.51_phase09753b.png
# Renaming phase09756a.png to 1_0.30_phase09756a.png
# Renaming phase09756b.png to 1_0.30_phase09756b.png
# Renaming phase09757a.png to 1_0.27_phase09757a.png
# Renaming phase09757b.png to 1_0.27_phase09757b.png
# Renaming phase09758a.png to 1_0.46_phase09758a.png
# Renaming phase09758b.png to 1_0.46_phase09758b.png
# Renaming phase09760a.png to 1_0.25_phase09760a.png
# Renaming phase09760b.png to 1_0.25_phase09760b.png
# Renaming phase09761a.png to 1_0.38_phase09761a.png
# Renaming phase09761b.png to 1_0.38_phase09761b.png
# Renaming phase09762a.png to 1_0.36_phase09762a.png
# Renaming phase09762b.png to 1_0.36_phase09762b.png
# Renaming phase09765a.png to 1_0.40_phase09765a.png
# Renaming phase09765b.png to 1_0.40_phase09765b.png
# Renaming phase09770a.png to 1_0.39_phase09770a.png
# Renaming phase09770b.png to 1_0.39_phase09770b.png
# Renaming phase09771a.png to 1_0.33_phase09771a.png
# Renaming phase09771b.png to 1_0.33_phase09771b.png
# Renaming phase09774a.png to 1_0.69_phase09774a.png
# Renaming phase09774b.png to 1_0.69_phase09774b.png
# Renaming phase09775a.png to 1_0.83_phase09775a.png
# Renaming phase09775b.png to 1_0.83_phase09775b.png
# Renaming phase09776a.png to 1_0.21_phase09776a.png
# Renaming phase09776b.png to 1_0.21_phase09776b.png
# Renaming phase09777a.png to 1_0.38_phase09777a.png
# Renaming phase09777b.png to 1_0.38_phase09777b.png
# Renaming phase09780a.png to 1_0.47_phase09780a.png
# Renaming phase09780b.png to 1_0.47_phase09780b.png
# Renaming phase09781a.png to 1_0.37_phase09781a.png
# Renaming phase09781b.png to 1_0.37_phase09781b.png
# Renaming phase09784a.png to 1_0.54_phase09784a.png
# Renaming phase09784b.png to 1_0.54_phase09784b.png
# Renaming phase09785a.png to 1_0.46_phase09785a.png
# Renaming phase09785b.png to 1_0.46_phase09785b.png
# Renaming phase09788a.png to 1_0.29_phase09788a.png
# Renaming phase09788b.png to 1_0.29_phase09788b.png
# Renaming phase09789a.png to 1_0.40_phase09789a.png
# Renaming phase09789b.png to 1_0.40_phase09789b.png
# Renaming phase09790a.png to 1_0.64_phase09790a.png
# Renaming phase09790b.png to 1_0.64_phase09790b.png
# Renaming phase09791a.png to 1_0.34_phase09791a.png
# Renaming phase09791b.png to 1_0.34_phase09791b.png
# Renaming phase09793a.png to 1_0.67_phase09793a.png
# Renaming phase09793b.png to 1_0.67_phase09793b.png
# Renaming phase09795a.png to 1_0.26_phase09795a.png
# Renaming phase09795b.png to 1_0.26_phase09795b.png
# Renaming phase09797a.png to 1_0.26_phase09797a.png
# Renaming phase09797b.png to 1_0.26_phase09797b.png
# Renaming phase09801a.png to 1_0.21_phase09801a.png
# Renaming phase09801b.png to 1_0.21_phase09801b.png
# Renaming phase09802a.png to 1_0.40_phase09802a.png
# Renaming phase09802b.png to 1_0.40_phase09802b.png
# Renaming phase09803a.png to 1_0.39_phase09803a.png
# Renaming phase09803b.png to 1_0.39_phase09803b.png
# Renaming phase09804a.png to 1_0.32_phase09804a.png
# Renaming phase09804b.png to 1_0.32_phase09804b.png
# Renaming phase09805a.png to 1_0.46_phase09805a.png
# Renaming phase09805b.png to 1_0.46_phase09805b.png
# Renaming phase09807a.png to 0_0.45_phase09807a.png
# Renaming phase09807b.png to 0_0.45_phase09807b.png
# Renaming phase09808a.png to 1_0.26_phase09808a.png
# Renaming phase09808b.png to 1_0.26_phase09808b.png
# Renaming phase09809a.png to 1_0.56_phase09809a.png
# Renaming phase09809b.png to 1_0.56_phase09809b.png
# Renaming phase09810a.png to 1_0.35_phase09810a.png
# Renaming phase09810b.png to 1_0.35_phase09810b.png
# Renaming phase09811a.png to 1_0.45_phase09811a.png
# Renaming phase09811b.png to 1_0.45_phase09811b.png
# Renaming phase09812a.png to 1_0.39_phase09812a.png
# Renaming phase09812b.png to 1_0.39_phase09812b.png
# Renaming phase09813a.png to 1_0.48_phase09813a.png
# Renaming phase09813b.png to 1_0.48_phase09813b.png
# Renaming phase09814a.png to 1_0.26_phase09814a.png
# Renaming phase09814b.png to 1_0.26_phase09814b.png
# Renaming phase09815a.png to 1_0.32_phase09815a.png
# Renaming phase09815b.png to 1_0.32_phase09815b.png
# Renaming phase09818a.png to 1_0.25_phase09818a.png
# Renaming phase09818b.png to 1_0.25_phase09818b.png
# Renaming phase09819a.png to 1_0.28_phase09819a.png
# Renaming phase09819b.png to 1_0.28_phase09819b.png
# Renaming phase09820a.png to 1_0.34_phase09820a.png
# Renaming phase09820b.png to 1_0.34_phase09820b.png
# Renaming phase09821a.png to 1_0.44_phase09821a.png
# Renaming phase09821b.png to 1_0.44_phase09821b.png
# Renaming phase09822a.png to 1_0.21_phase09822a.png
# Renaming phase09822b.png to 1_0.21_phase09822b.png
# Renaming phase09823a.png to 1_0.26_phase09823a.png
# Renaming phase09823b.png to 1_0.26_phase09823b.png
# Renaming phase09824a.png to 1_0.37_phase09824a.png
# Renaming phase09824b.png to 1_0.37_phase09824b.png
# Renaming phase09826a.png to 1_0.29_phase09826a.png
# Renaming phase09826b.png to 1_0.29_phase09826b.png
# Renaming phase09827a.png to 1_0.51_phase09827a.png
# Renaming phase09827b.png to 1_0.51_phase09827b.png
# Renaming phase09828a.png to 1_0.24_phase09828a.png
# Renaming phase09828b.png to 1_0.24_phase09828b.png
# Renaming phase09830a.png to 1_0.29_phase09830a.png
# Renaming phase09830b.png to 1_0.29_phase09830b.png
# Renaming phase09831a.png to 1_0.29_phase09831a.png
# Renaming phase09831b.png to 1_0.29_phase09831b.png
# Renaming phase09832a.png to 1_0.37_phase09832a.png
# Renaming phase09832b.png to 1_0.37_phase09832b.png
# Renaming phase09833a.png to 1_0.55_phase09833a.png
# Renaming phase09833b.png to 1_0.55_phase09833b.png
# Renaming phase09835a.png to 1_0.27_phase09835a.png
# Renaming phase09835b.png to 1_0.27_phase09835b.png
# Renaming phase09836a.png to 1_0.43_phase09836a.png
# Renaming phase09836b.png to 1_0.43_phase09836b.png
# Renaming phase09837a.png to 1_0.36_phase09837a.png
# Renaming phase09837b.png to 1_0.36_phase09837b.png
# Renaming phase09838a.png to 1_0.32_phase09838a.png
# Renaming phase09838b.png to 1_0.32_phase09838b.png
# Renaming phase09840a.png to 1_0.28_phase09840a.png
# Renaming phase09840b.png to 1_0.28_phase09840b.png
# Renaming phase09842a.png to 1_0.24_phase09842a.png
# Renaming phase09842b.png to 1_0.24_phase09842b.png
# Renaming phase09846a.png to 1_0.42_phase09846a.png
# Renaming phase09846b.png to 1_0.42_phase09846b.png
# Renaming phase09848a.png to 1_0.54_phase09848a.png
# Renaming phase09848b.png to 1_0.54_phase09848b.png
# Renaming phase09849a.png to 1_0.26_phase09849a.png
# Renaming phase09849b.png to 1_0.26_phase09849b.png
# Renaming phase09851a.png to 0_0.23_phase09851a.png
# Renaming phase09851b.png to 0_0.23_phase09851b.png
# Renaming phase09852a.png to 1_0.36_phase09852a.png
# Renaming phase09852b.png to 1_0.36_phase09852b.png
# Renaming phase09853a.png to 1_0.31_phase09853a.png
# Renaming phase09853b.png to 1_0.31_phase09853b.png
# Renaming phase09858a.png to 1_0.21_phase09858a.png
# Renaming phase09858b.png to 1_0.21_phase09858b.png
# Renaming phase09859a.png to 1_0.77_phase09859a.png
# Renaming phase09859b.png to 1_0.77_phase09859b.png
# Renaming phase09861a.png to 1_0.42_phase09861a.png
# Renaming phase09861b.png to 1_0.42_phase09861b.png
# Renaming phase09862a.png to 1_0.42_phase09862a.png
# Renaming phase09862b.png to 1_0.42_phase09862b.png
# Renaming phase09867a.png to 1_0.53_phase09867a.png
# Renaming phase09867b.png to 1_0.53_phase09867b.png
# Renaming phase09868a.png to 1_0.40_phase09868a.png
# Renaming phase09868b.png to 1_0.40_phase09868b.png
# Renaming phase09869a.png to 1_0.40_phase09869a.png
# Renaming phase09869b.png to 1_0.40_phase09869b.png
# Renaming phase09870a.png to 1_0.34_phase09870a.png
# Renaming phase09870b.png to 1_0.34_phase09870b.png
# Renaming phase09871a.png to 1_0.20_phase09871a.png
# Renaming phase09871b.png to 1_0.20_phase09871b.png
# Renaming phase09872a.png to 1_0.26_phase09872a.png
# Renaming phase09872b.png to 1_0.26_phase09872b.png
# Renaming phase09876a.png to 1_0.40_phase09876a.png
# Renaming phase09876b.png to 1_0.40_phase09876b.png
# Renaming phase09878a.png to 0_0.25_phase09878a.png
# Renaming phase09878b.png to 0_0.25_phase09878b.png
# Renaming phase09879a.png to 1_0.47_phase09879a.png
# Renaming phase09879b.png to 1_0.47_phase09879b.png
# Renaming phase09881a.png to 1_0.27_phase09881a.png
# Renaming phase09881b.png to 1_0.27_phase09881b.png
# Renaming phase09883a.png to 1_0.23_phase09883a.png
# Renaming phase09883b.png to 1_0.23_phase09883b.png
# Renaming phase09884a.png to 1_0.27_phase09884a.png
# Renaming phase09884b.png to 1_0.27_phase09884b.png
# Renaming phase09885a.png to 1_0.23_phase09885a.png
# Renaming phase09885b.png to 1_0.23_phase09885b.png
# Renaming phase09886a.png to 1_0.51_phase09886a.png
# Renaming phase09886b.png to 1_0.51_phase09886b.png
# Renaming phase09887a.png to 1_0.17_phase09887a.png
# Renaming phase09887b.png to 1_0.17_phase09887b.png
# Renaming phase09888a.png to 1_0.29_phase09888a.png
# Renaming phase09888b.png to 1_0.29_phase09888b.png
# Renaming phase09889a.png to 1_0.33_phase09889a.png
# Renaming phase09889b.png to 1_0.33_phase09889b.png
# Renaming phase09890a.png to 1_0.41_phase09890a.png
# Renaming phase09890b.png to 1_0.41_phase09890b.png
# Renaming phase09891a.png to 1_0.51_phase09891a.png
# Renaming phase09891b.png to 1_0.51_phase09891b.png
# Renaming phase09892a.png to 0_0.64_phase09892a.png
# Renaming phase09892b.png to 0_0.64_phase09892b.png
# Renaming phase09894a.png to 1_0.34_phase09894a.png
# Renaming phase09894b.png to 1_0.34_phase09894b.png
# Renaming phase09896a.png to 1_0.41_phase09896a.png
# Renaming phase09896b.png to 1_0.41_phase09896b.png
# Renaming phase09899a.png to 1_0.71_phase09899a.png
# Renaming phase09899b.png to 1_0.71_phase09899b.png
# Renaming phase09902a.png to 1_0.79_phase09902a.png
# Renaming phase09902b.png to 1_0.79_phase09902b.png
# Renaming phase09903a.png to 1_0.34_phase09903a.png
# Renaming phase09903b.png to 1_0.34_phase09903b.png
# Renaming phase09905a.png to 1_0.26_phase09905a.png
# Renaming phase09905b.png to 1_0.26_phase09905b.png
# Renaming phase09908a.png to 1_0.37_phase09908a.png
# Renaming phase09908b.png to 1_0.37_phase09908b.png
# Renaming phase09909a.png to 1_0.24_phase09909a.png
# Renaming phase09909b.png to 1_0.24_phase09909b.png
# Renaming phase09911a.png to 1_0.56_phase09911a.png
# Renaming phase09911b.png to 1_0.56_phase09911b.png
# Renaming phase09912a.png to 1_0.27_phase09912a.png
# Renaming phase09912b.png to 1_0.27_phase09912b.png
# Renaming phase09913a.png to 1_0.76_phase09913a.png
# Renaming phase09913b.png to 1_0.76_phase09913b.png
# Renaming phase09915a.png to 1_0.33_phase09915a.png
# Renaming phase09915b.png to 1_0.33_phase09915b.png
# Renaming phase09916a.png to 1_0.31_phase09916a.png
# Renaming phase09916b.png to 1_0.31_phase09916b.png
# Renaming phase09919a.png to 1_0.31_phase09919a.png
# Renaming phase09919b.png to 1_0.31_phase09919b.png
# Renaming phase09921a.png to 1_0.36_phase09921a.png
# Renaming phase09921b.png to 1_0.36_phase09921b.png
# Renaming phase09923a.png to 1_0.32_phase09923a.png
# Renaming phase09923b.png to 1_0.32_phase09923b.png
# Renaming phase09925a.png to 1_0.27_phase09925a.png
# Renaming phase09925b.png to 1_0.27_phase09925b.png
# Renaming phase09926a.png to 1_0.58_phase09926a.png
# Renaming phase09926b.png to 1_0.58_phase09926b.png
# Renaming phase09931a.png to 1_0.23_phase09931a.png
# Renaming phase09931b.png to 1_0.23_phase09931b.png
# Renaming phase09932a.png to 1_0.45_phase09932a.png
# Renaming phase09932b.png to 1_0.45_phase09932b.png
# Renaming phase09933a.png to 1_0.32_phase09933a.png
# Renaming phase09933b.png to 1_0.32_phase09933b.png
# Renaming phase09936a.png to 1_0.33_phase09936a.png
# Renaming phase09936b.png to 1_0.33_phase09936b.png
# Renaming phase09937a.png to 1_0.33_phase09937a.png
# Renaming phase09937b.png to 1_0.33_phase09937b.png
# Renaming phase09940a.png to 1_0.23_phase09940a.png
# Renaming phase09940b.png to 1_0.23_phase09940b.png
# Renaming phase09942a.png to 1_0.27_phase09942a.png
# Renaming phase09942b.png to 1_0.27_phase09942b.png
# Renaming phase09943a.png to 1_0.27_phase09943a.png
# Renaming phase09943b.png to 1_0.27_phase09943b.png
# Renaming phase09949a.png to 1_0.34_phase09949a.png
# Renaming phase09949b.png to 1_0.34_phase09949b.png
# Renaming phase09950a.png to 1_0.20_phase09950a.png
# Renaming phase09950b.png to 1_0.20_phase09950b.png
# Renaming phase09953a.png to 1_0.29_phase09953a.png
# Renaming phase09953b.png to 1_0.29_phase09953b.png
# Renaming phase09954a.png to 1_0.25_phase09954a.png
# Renaming phase09954b.png to 1_0.25_phase09954b.png
# Renaming phase09955a.png to 1_0.44_phase09955a.png
# Renaming phase09955b.png to 1_0.44_phase09955b.png
# Renaming phase09956a.png to 1_0.35_phase09956a.png
# Renaming phase09956b.png to 1_0.35_phase09956b.png
# Renaming phase09957a.png to 1_0.22_phase09957a.png
# Renaming phase09957b.png to 1_0.22_phase09957b.png
# Renaming phase09958a.png to 1_0.23_phase09958a.png
# Renaming phase09958b.png to 1_0.23_phase09958b.png
# Renaming phase09960a.png to 1_0.49_phase09960a.png
# Renaming phase09960b.png to 1_0.49_phase09960b.png
# Renaming phase09961a.png to 1_0.50_phase09961a.png
# Renaming phase09961b.png to 1_0.50_phase09961b.png
# Renaming phase09962a.png to 1_0.29_phase09962a.png
# Renaming phase09962b.png to 1_0.29_phase09962b.png
# Renaming phase09963a.png to 1_0.66_phase09963a.png
# Renaming phase09963b.png to 1_0.66_phase09963b.png
# Renaming phase09964a.png to 1_0.31_phase09964a.png
# Renaming phase09964b.png to 1_0.31_phase09964b.png
# Renaming phase09966a.png to 1_0.28_phase09966a.png
# Renaming phase09966b.png to 1_0.28_phase09966b.png
# Renaming phase09967a.png to 1_0.48_phase09967a.png
# Renaming phase09967b.png to 1_0.48_phase09967b.png
# Renaming phase09968a.png to 1_0.50_phase09968a.png
# Renaming phase09968b.png to 1_0.50_phase09968b.png
# Renaming phase09978a.png to 1_0.52_phase09978a.png
# Renaming phase09978b.png to 1_0.52_phase09978b.png
# Renaming phase09980a.png to 1_0.60_phase09980a.png
# Renaming phase09980b.png to 1_0.60_phase09980b.png
# Renaming phase09982a.png to 1_0.57_phase09982a.png
# Renaming phase09982b.png to 1_0.57_phase09982b.png
# Renaming phase09983a.png to 1_0.42_phase09983a.png
# Renaming phase09983b.png to 1_0.42_phase09983b.png
# Renaming phase09984a.png to 1_0.26_phase09984a.png
# Renaming phase09984b.png to 1_0.26_phase09984b.png
# Renaming phase09985a.png to 1_0.27_phase09985a.png
# Renaming phase09985b.png to 1_0.27_phase09985b.png
# Renaming phase09986a.png to 1_0.61_phase09986a.png
# Renaming phase09986b.png to 1_0.61_phase09986b.png
# Renaming phase09987a.png to 0_0.38_phase09987a.png
# Renaming phase09987b.png to 0_0.38_phase09987b.png
# Renaming phase09990a.png to 1_0.38_phase09990a.png
# Renaming phase09990b.png to 1_0.38_phase09990b.png
# Renaming phase09992a.png to 0_0.25_phase09992a.png
# Renaming phase09992b.png to 0_0.25_phase09992b.png
# Renaming phase09998a.png to 1_0.41_phase09998a.png
# Renaming phase09998b.png to 1_0.41_phase09998b.png

# %%
ups
