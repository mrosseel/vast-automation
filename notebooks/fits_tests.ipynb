# %% [markdown]
# # Visualising FITS and star positions

# %%
import os
os.chdir('..')
import numpy as np
import init

# Set up matplotlib and use a nicer set of plot parameters
# %config InlineBackend.rc = {}
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from astropy.io import fits

# %%
reference_frame = init.convfitsdir+"kout000546.fts"
image_file = open(reference_frame, "rb")
#wcs_file = open(init.basedir+"new-image.fits", "rb")r

# %%
hdu_list = fits.open(wcs_file)
hdu_list.info()
# Out:
# Filename: ./inputfiles/WWCrA2015/new-image.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     253   (1365, 1365)   int16 (rescales to uint16)

# %%
image_data = hdu_list[0].data

# %%
print(type(image_data))
print(image_data.shape)
# Out:
# <class 'numpy.ndarray'>
# (1365, 1365)

# %%
hdu_list.close()

# %%
import aplpy
gc = aplpy.FITSFigure(reference_frame)
# use http://www.astrouw.edu.pl/~jskowron/ra-dec/?q=18%3A05%3A36.79+-43%3A49%3A57.4
# Choose RA (deg) en DEC (deg)
ra_deg = 271.4032917
dec_deg = -43.8326111
gc.add_label(ra_deg, dec_deg, 'WW CrA')
gc.show_colorscale(cmap='viridis')
# Out:
# WARNING: No WCS information found in header - using pixel coordinates [aplpy.header]
# INFO: Auto-setting vmin to  7.889e+01 [aplpy.core]
# INFO: Auto-setting vmax to  4.068e+02 [aplpy.core]

# %%
x_pix, y_pix = gc.world2pixel(ra_deg, dec_deg)
# x_world, y_world = gc.pixel2world(np.array([700]), np.array([700]))
print(x_pix, y_pix)
# Out:
# 962.856994023 711.327534113
