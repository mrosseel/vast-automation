# %%
import pandas as pd
# %matplotlib notebook

# %%
df = pd.read_csv('../tests/zonebucket.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-2ff82a0945eb> in <module>
# ----> 1 df = pd.read_csv('../tests/zonebucket.csv')
#       2 df.head()
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# ...

# %%
for entry in range(1, 1441):
    df2 = df[df['bucket'] == entry]
    if len(df2) > 0:
        print(f"Entry: {entry},\tmin: {df2['min_ras'].min():.2f},\tmax: {df2['max_ras'].max():.2f}")
# Out:
# Entry: 1,	min: 0.00,	max: 0.25
# Entry: 2,	min: 0.25,	max: 0.50
# Entry: 3,	min: 0.50,	max: 0.75
# Entry: 4,	min: 0.75,	max: 1.00
# Entry: 5,	min: 1.00,	max: 1.25
# Entry: 6,	min: 1.25,	max: 1.50
# Entry: 7,	min: 1.50,	max: 1.75
# Entry: 8,	min: 1.75,	max: 2.00
# Entry: 9,	min: 2.00,	max: 2.25
# Entry: 10,	min: 2.25,	max: 2.50
# Entry: 11,	min: 2.50,	max: 2.75
# Entry: 12,	min: 2.75,	max: 3.00
# Entry: 13,	min: 3.00,	max: 3.25
# Entry: 14,	min: 3.25,	max: 3.50
# Entry: 15,	min: 3.50,	max: 3.75
# Entry: 16,	min: 3.75,	max: 4.00
# Entry: 17,	min: 4.00,	max: 4.25
# Entry: 18,	min: 4.25,	max: 4.50
# Entry: 19,	min: 4.50,	max: 4.75
# Entry: 20,	min: 4.75,	max: 5.00
# Entry: 21,	min: 5.00,	max: 5.25
# Entry: 22,	min: 5.25,	max: 5.50
# Entry: 23,	min: 5.50,	max: 5.75
# Entry: 24,	min: 5.75,	max: 6.00
# Entry: 25,	min: 6.00,	max: 6.25
# Entry: 26,	min: 6.25,	max: 6.50
# Entry: 27,	min: 6.50,	max: 6.75
# Entry: 28,	min: 6.75,	max: 7.00
# Entry: 29,	min: 7.00,	max: 7.25
# ...

# %%
df.plot()
# Out:
# <div id='54fe1d58-2372-4af6-bf3b-fc937bbdf824'></div>
